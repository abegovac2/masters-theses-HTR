# %% [markdown]
# ## File conversion from .gif to .jpg

# %% [markdown]
# ### Setup folders

# %%
import os

def setup_folders(input: str, output):
    input_folders = [
        f"./{input}/FormatA",
        f"./{input}/FormatB"
    ]
    output_folders = [
        f"./{output}/FormatA",
        f"./{output}/FormatB",
    ]

    if not os.path.isdir(f"./{output}"):
        os.mkdir(f"./{output}")
    if not os.path.isdir(f"./{output}/FormatA"):
        os.mkdir(f"./{output}/FormatA")
    if not os.path.isdir(f"./{output}/FormatB"):
        os.mkdir(f"./{output}/FormatB")

    return input_folders, output_folders


input_folders, output_folders = setup_folders("MINSKI_ZAPISNICI_SORTIRANO_ZAJEDNO","jpg_minski_zapisnici")

# %% [markdown]
# ### Convert images

# %%
from utils import convert_gif_to_jpg
from time import time

num_threads = 5

folders = list(zip(input_folders, output_folders))
for input_folder, output_folder in folders:
    print(f"Folder {input_folder}")
    print("Start convert...")
    s = time()
    convert_gif_to_jpg(input_folder, output_folder, num_threads)
    e = time()
    print(f"End convert, time took {e-s}")
# Out:
# Folder ./MINSKI_ZAPISNICI_SORTIRANO_ZAJEDNO/FormatA
# Start convert...
# Converted 30519.gif to JPG
# Converted 30520.gif to JPG
# Converted 30706.gif to JPG
# Converted 30535.gif to JPG
# Converted 30543.gif to JPG
# Converted 30960.gif to JPG
# Converted 30926.gif to JPG
# Converted 30967.gif to JPG
# Converted 30925.gif to JPG
# Converted 30922.gif to JPG
# Converted 30969.gif to JPG
# Converted 30972.gif to JPG
# Converted 30977a.gif to JPG
# Converted 31131.gif to JPG
# Converted 31094.gif to JPG
# Converted 31142.gif to JPG
# Converted 31139.gif to JPG
# Converted 31150.gif to JPG
# Converted 31136.gif to JPG
# Converted 31138.gif to JPG
# Converted 33021a.gif to JPG
# Converted 32862.gif to JPG
# Converted 33021b.gif to JPG
# Converted 32860.gif to JPG
# Converted 31190.gif to JPG
# Converted 40688.gif to JPG
# Converted 50677.gif to JPG
# Converted 50678.gif to JPG
# Converted 50676.gif to JPG
# Converted 33238.gif to JPG
# Converted 50690.gif to JPG
# Converted 50685.gif to JPG
# Converted 50684.gif to JPG
# Converted 50682.gif to JPG
# Converted 50689.gif to JPG
# Converted 50691.gif to JPG
# Converted 51356.gif to JPG
# Converted 51355.gif to JPG
# Converted 51358.gif to JPG
# Converted 51357.gif to JPG
# Converted 51362.gif to JPG
# Converted 51359.gif to JPG
# Converted 51363.gif to JPG
# Converted 51361.gif to JPG
# Converted 51364.gif to JPG
# Converted 51385.gif to JPG
# Converted 51374.gif to JPG
# Converted 51365.gif to JPG
# Converted gp 835.gif to JPG
# Converted gp 750.gif to JPG
# Converted gp 838.gif to JPG
# Converted gp 839.gif to JPG
# Converted gp 892.gif to JPG
# Converted gp 982.gif to JPG
# Converted gp1002b.gif to JPG
# Converted gp1028.gif to JPG
# Converted gp1027.gif to JPG
# Converted gp1029.gif to JPG
# Converted gp1026.gif to JPG
# Converted gp1025.gif to JPG
# Converted gp1033.gif to JPG
# Converted gp1032.gif to JPG
# Converted gp1031.gif to JPG
# Converted gp1034.gif to JPGConverted gp1030.gif to JPG
#
# Converted gp1219.gif to JPG
# Converted gp1328.gif to JPG
# Converted gp1330.gif to JPG
# Converted gp1331.gif to JPG
# Converted gp1329.gif to JPG
# Converted gp1334.gif to JPG
# Converted gp1336.gif to JPG
# Converted gp1333.gif to JPG
# Converted gp1335.gif to JPG
# Converted gp1332.gif to JPG
# Converted gp1338.gif to JPG
# Converted gp1341b.gif to JPG
# Converted gp1339.gif to JPG
# Converted gp1342.gif to JPG
# Converted gp1337.gif to JPG
# Converted gp1650.gif to JPG
# Converted gp1649.gif to JPG
# Converted gp1648.gif to JPG
# Converted gp1642.gif to JPG
# Converted gp1651.gif to JPG
# Converted gp1657.gif to JPG
# Converted gp1652.gif to JPG
# Converted gp1654.gif to JPG
# Converted gp1658.gif to JPG
# Converted gp1656.gif to JPG
# Converted gp1661.gif to JPG
# Converted gp1658b.gif to JPG
# Converted gp1660.gif to JPG
# Converted gp1659.gif to JPG
# Converted gp1667.gif to JPG
# Converted gp1761.gif to JPG
# Converted gp1673.gif to JPG
# Converted gp1671.gif to JPG
# Converted gp1669.gif to JPG
# Converted gp1674.gif to JPG
# Converted gp2176.gif to JPG
# Converted gp2175.gif to JPG
# Converted gp2177.gif to JPG
# Converted gp2260.gif to JPG
# Converted gp2259.gif to JPG
# Converted hcr_31144b.gif to JPG
# Converted hcr_31133b.gif to JPG
# Converted hcr_31144a.gif to JPG
# Converted hcr_31133a.gif to JPG
# Converted gp2261.gif to JPG
# Converted un1041b.gif to JPG
# Converted un1080.gif to JPG
# Converted un1027.gif to JPG
# Converted un1041a.gif to JPG
# Converted un1090.gif to JPG
# Converted un1118.gif to JPG
# Converted un1177.gif to JPG
# Converted un1091.gif to JPG
# Converted un1178.gif to JPG
# Converted un1182.gif to JPG
# Converted un1188.gif to JPG
# Converted un1239.gif to JPG
# Converted un1194.gif to JPG
# Converted un1184.gif to JPG
# Converted un1183.gif to JPG
# Converted un1246.gif to JPG
# Converted un1242.gif to JPG
# Converted un1269a.gif to JPG
# Converted un1247.gif to JPG
# Converted un1243.gif to JPG
# Converted un1269b.gif to JPG
# Converted un1271.gif to JPG
# Converted un1272b.gif to JPG
# Converted un1272a.gif to JPG
# Converted un1270.gif to JPG
# Converted un951.gif to JPG
# Converted un1274.gif to JPG
# Converted zmp112.gif to JPG
# Converted zmp113.gif to JPG
# Converted zmp111.gif to JPG
# Converted zmp121.gif to JPG
# Converted zmp114.gif to JPG
# Converted zmp122.gif to JPG
# Converted zmp119.gif to JPG
# Converted zmp118.gif to JPG
# Converted zmp126.gif to JPG
# Converted zmp125.gif to JPG
# Converted zmp124.gif to JPG
# Converted zmp123.gif to JPG
# Converted zmp127.gif to JPG
# Converted zmp128.gif to JPG
# Converted zmp129.gif to JPG
# Converted zmp130.gif to JPG
# Converted zmp131.gif to JPG
# Converted zmp132.gif to JPG
# Converted zmp135.gif to JPG
# Converted zmp136.gif to JPG
# Converted zmp134.gif to JPG
# Converted zmp133.gif to JPG
# Converted zmp137.gif to JPG
# Converted zmp142.gif to JPG
# Converted zmp140.gif to JPG
# Converted zmp138.gif to JPG
# Converted zmp139.gif to JPG
# Converted zmp141.gif to JPG
# Converted zmp146.gif to JPG
# Converted zmp144.gif to JPG
# Converted zmp149.gif to JPG
# Converted zmp150.gif to JPG
# Converted zmp147.gif to JPG
# Converted zmp151.gif to JPG
# Converted zmp154.gif to JPG
# Converted zmp155.gif to JPG
# Converted zmp153.gif to JPG
# Converted zmp152.gif to JPG
# Converted zmp158.gif to JPG
# Converted zmp157.gif to JPG
# Converted zmp160.gif to JPG
# Converted zmp156.gif to JPG
# Converted zmp159.gif to JPG
# Converted zmp163.gif to JPG
# Converted zmp164.gif to JPG
# Converted zmp162.gif to JPG
# Converted zmp161.gif to JPG
# Converted zmp165.gif to JPG
# Converted zmp168.gif to JPG
# Converted zmp166.gif to JPG
# Converted zmp167.gif to JPG
# Converted zmp169.gif to JPG
# Converted zmp170.gif to JPG
# Converted zmp171.gif to JPG
# Converted zmp172.gif to JPG
# End convert, time took 3.7930614948272705
# Folder ./MINSKI_ZAPISNICI_SORTIRANO_ZAJEDNO/FormatB
# Start convert...
# Converted 31146b.gif to JPG
# Converted 31146a.gif to JPG
# Converted 31164.gif to JPG
# Converted 31153.gif to JPG
# Converted 31163a.gif to JPG
# Converted 31165.gif to JPG
# Converted 31169b.gif to JPG
# Converted 31167.gif to JPG
# Converted 31171.gif to JPG
# Converted 31169a.gif to JPG
# Converted hcr_31157a.gif to JPG
# Converted hcr_31157b.gif to JPG
# End convert, time took 0.29419994354248047

# %% [markdown]
# ## Cleaning images

# %%
input_folders, output_folders = setup_folders("jpg_minski_zapisnici", "jpg_minski_zapisnici_clean")

# %%
from utils.clean_image_pipeline import apply_image_cleaning_pipeline

input_path = "./jpg_minski_zapisnici/FormatA/30543.jpg"
output_path = "./jpg_minski_zapisnici_clean/FormatA/30543.jpg"

apply_image_cleaning_pipeline(input_path, output_path)

# %%
from time import time
from utils.clean_image_pipeline import apply_image_cleaning_pipeline
import threading

num_threads = 5
folders = list(zip(input_folders, output_folders))
for input_folder, output_folder in folders:
    print(f"Folder {input_folder}")
    print("Start clean...")
    s = time()
    images = os.listdir(input_folder)
    threads = []

    for in_image in images:
        image1, image2 = f"{input_folder}/{in_image}", f"{output_folder}/{in_image}"
        print("In: ", image1)
        print("Out: ", image2)
        thread = threading.Thread(target=apply_image_cleaning_pipeline, args=(image1, image2))
        thread.start()
        threads.append(thread)
        if len(threads) >= num_threads:
            for thread in threads:
                thread.join()
            threads = []
        #apply_image_cleaning_pipeline(image1, image2)
    e = time()
    print(f"End clean, time took {e-s}")
# Out:
# Folder ./jpg_minski_zapisnici/FormatA
# Start clean...
# In:  ./jpg_minski_zapisnici/FormatA/30519.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30519.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30520.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30520.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30535.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30535.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30543.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30543.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30706.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30706.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30922.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30922.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30925.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30925.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30926.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30926.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30960.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30960.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30967.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30967.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30969.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30969.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30972.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30972.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30977a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30977a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31094.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31094.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31131.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31131.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31136.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31136.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31138.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31138.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31139.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31139.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31142.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31142.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31150.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31150.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31190.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31190.jpg
# In:  ./jpg_minski_zapisnici/FormatA/32860.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/32860.jpg
# In:  ./jpg_minski_zapisnici/FormatA/32862.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/32862.jpg
# In:  ./jpg_minski_zapisnici/FormatA/33021a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/33021a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/33021b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/33021b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/33238.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/33238.jpg
# In:  ./jpg_minski_zapisnici/FormatA/40688.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/40688.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50676.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50676.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50677.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50677.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50678.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50678.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50682.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50682.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50684.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50684.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50685.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50685.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50689.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50689.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50690.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50690.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50691.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50691.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51355.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51355.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51356.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51356.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51357.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51357.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51358.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51358.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51359.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51359.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51361.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51361.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51362.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51362.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51363.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51363.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51364.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51364.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51365.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51365.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51374.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51374.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51385.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51385.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 750.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 750.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 835.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 835.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 838.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 838.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 839.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 839.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 892.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 892.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 982.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 982.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1002b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1002b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1025.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1025.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1026.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1026.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1027.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1027.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1028.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1028.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1029.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1029.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1030.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1030.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1031.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1031.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1032.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1032.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1033.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1033.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1034.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1034.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1219.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1219.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1328.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1328.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1329.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1329.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1330.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1330.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1331.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1331.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1332.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1332.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1333.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1333.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1334.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1334.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1335.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1335.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1336.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1336.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1337.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1337.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1338.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1338.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1339.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1339.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1341b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1341b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1342.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1342.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1642.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1642.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1648.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1648.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1649.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1649.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1650.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1650.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1651.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1651.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1652.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1652.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1654.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1654.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1656.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1656.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1657.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1657.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1658.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1658.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1658b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1658b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1659.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1659.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1660.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1660.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1661.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1661.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1667.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1667.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1669.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1669.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1671.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1671.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1673.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1673.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1674.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1674.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1761.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1761.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2175.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2175.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2176.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2176.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2177.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2177.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2259.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2259.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2260.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2260.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2261.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2261.jpg
# In:  ./jpg_minski_zapisnici/FormatA/hcr_31133a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/hcr_31133a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/hcr_31133b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/hcr_31133b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/hcr_31144a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/hcr_31144a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/hcr_31144b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/hcr_31144b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1027.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1027.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1041a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1041a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1041b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1041b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1080.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1080.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1090.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1090.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1091.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1091.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1118.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1118.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1177.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1177.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1178.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1178.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1182.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1182.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1183.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1183.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1184.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1184.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1188.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1188.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1194.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1194.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1239.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1239.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1242.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1242.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1243.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1243.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1246.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1246.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1247.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1247.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1269a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1269a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1269b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1269b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1270.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1270.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1271.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1271.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1272a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1272a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1272b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1272b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1274.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1274.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un951.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un951.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp111.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp111.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp112.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp112.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp113.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp113.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp114.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp114.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp118.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp118.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp119.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp119.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp121.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp121.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp122.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp122.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp123.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp123.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp124.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp124.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp125.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp125.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp126.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp126.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp127.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp127.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp128.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp128.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp129.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp129.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp130.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp130.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp131.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp131.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp132.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp132.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp133.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp133.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp134.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp134.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp135.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp135.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp136.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp136.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp137.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp137.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp138.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp138.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp139.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp139.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp140.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp140.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp141.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp141.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp142.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp142.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp144.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp144.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp146.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp146.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp147.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp147.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp149.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp149.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp150.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp150.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp151.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp151.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp152.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp152.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp153.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp153.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp154.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp154.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp155.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp155.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp156.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp156.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp157.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp157.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp158.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp158.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp159.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp159.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp160.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp160.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp161.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp161.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp162.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp162.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp163.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp163.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp164.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp164.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp165.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp165.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp166.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp166.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp167.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp167.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp168.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp168.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp169.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp169.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp170.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp170.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp171.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp171.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp172.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp172.jpg
# End clean, time took 131.79463052749634
# Folder ./jpg_minski_zapisnici/FormatB
# Start clean...
# In:  ./jpg_minski_zapisnici/FormatB/31146a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31146a.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31146b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31146b.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31153.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31153.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31163a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31163a.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31164.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31164.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31165.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31165.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31167.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31167.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31169a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31169a.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31169b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31169b.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31171.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31171.jpg
# In:  ./jpg_minski_zapisnici/FormatB/hcr_31157a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/hcr_31157a.jpg
# In:  ./jpg_minski_zapisnici/FormatB/hcr_31157b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/hcr_31157b.jpg
# End clean, time took 8.650370597839355

# %% [markdown]
# ## Region detection

# %% [markdown]
# ### Manual region detection

# %%
from utils.extract_regions import extract_interesting_regions
import cv2
image_path = "./jpg_minski_zapisnici_clean/FormatA/30543.jpg"
out_path = "./tmp/region_detection12_"

image = cv2.imread(image_path)
regions = extract_interesting_regions(image)

for i, region in enumerate(regions):
    a = f"{out_path}{i}.jpg"
    print(a)
    if len(region) > 0:
        print("write")
        cv2.imwrite(a, region)
# Out:
# ./tmp/region_detection12_0.jpg
# write
# ./tmp/region_detection12_1.jpg
# write
# ./tmp/region_detection12_2.jpg
# write
# ./tmp/region_detection12_3.jpg
# write
# ./tmp/region_detection12_4.jpg
# write
# ./tmp/region_detection12_5.jpg
# write
# ./tmp/region_detection12_6.jpg
# write
# ./tmp/region_detection12_7.jpg
# write

# %%
input_folders, output_folders = setup_folders("jpg_minski_zapisnici_clean","jpg_minski_zapisnici_clean_manual_regions")

# %%
from time import time
from utils.extract_regions import extract_interesting_regions
import threading

def extract_interesting_regions_threading(src: str, dest: str):
    empty, dest, ext = dest.split('.')
    image = cv2.imread(src)
    regions = extract_interesting_regions(image)

    for i, region in enumerate(regions):
        a = f".{dest}_{i}.{ext}"
        if len(region) > 0:
            cv2.imwrite(a, region)

num_threads = 5
folders = list(zip(input_folders, output_folders))
for input_folder, output_folder in folders:
    print(f"Folder {input_folder}")
    print("Start clean...")
    s = time()
    images = os.listdir(input_folder)
    threads = []

    for in_image in images:
        image1, image2 = f"{input_folder}/{in_image}", f"{output_folder}/{in_image}"
        print("In: ", image1)
        print("Out: ", image2)
        #extract_interesting_regions_threading(image1, image2)
        #"""
        thread = threading.Thread(target=extract_interesting_regions_threading, args=(image1, image2))
        thread.start()
        threads.append(thread)
        if len(threads) >= num_threads:
            for thread in threads:
                thread.join()
            threads = []
        #"""
    e = time()
    print(f"End clean, time took {e-s}")

# %% [markdown]
# Results not good, because of the state of the images the line detection, which is predominantly used for this action, cannot work correctly most of the time.
# Best way is to use ML assistance for this work.

# %% [markdown]
# ### ML region detection

# %%
# !pip install ultralytics==8.0.227

# %%
from ultralytics import YOLO

model_path = "./models/region_detection_model.pt"
img_path = "./jpg_minski_zapisnici_clean/FormatA/30519.jpg"
model = YOLO(model_path)
import cv2
image = cv2.imread(img_path)

results = model.predict(source=image, imgsz=640,conf=0.25,iou=0.45)
results = results[0]  
for i in range(len(results.boxes)):
        box = results.boxes[i]
        cls = results.cls
        tensor = box.xyxy[0]
        x1 = int(tensor[0].item())
        y1 = int(tensor[1].item())
        x2 = int(tensor[2].item())
        y2 = int(tensor[3].item())
        cv2.rectangle(image,(x1,y1),(x2,y2),(255,0,0),3) 

a= "./tmp/30519-regions-drawings.jpg"
cv2.imwrite(a,image)
# Out:
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 179.8ms
# Speed: 10.2ms preprocess, 179.8ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 480)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 13
#      11 for i in range(len(results.boxes)):
#      12         box = results.boxes[i]
# ---> 13         cls = results.cls
#      14         tensor = box.xyxy[0]
#      15         x1 = int(tensor[0].item())
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\ultralytics\utils\__init__.py:153, in SimpleClass.__getattr__(self, attr)
#     151 """Custom attribute access error message with helpful information."""
#     152 name = self.__class__.__name__
# --> 153 raise AttributeError(f"'{name}' object has no attribute '{attr}'. See valid attributes below.\n{self.__doc__}")
#
# AttributeError: 'Results' object has no attribute 'cls'. See valid attributes below.
#
#     A class for storing and manipulating inference results.
#
#     Args:
#         orig_img (numpy.ndarray): The original image as a numpy array.
#         path (str): The path to the image file.
#         names (dict): A dictionary of class names.
#         boxes (torch.tensor, optional): A 2D tensor of bounding box coordinates for each detection.
#         masks (torch.tensor, optional): A 3D tensor of detection masks, where each mask is a binary image.
#         probs (torch.tensor, optional): A 1D tensor of probabilities of each class for classification task.
#         keypoints (List[List[float]], optional): A list of detected keypoints for each object.
#
#     Attributes:
#         orig_img (numpy.ndarray): The original image as a numpy array.
#         orig_shape (tuple): The original image shape in (height, width) format.
#         boxes (Boxes, optional): A Boxes object containing the detection bounding boxes.
#         masks (Masks, optional): A Masks object containing the detection masks.
#         probs (Probs, optional): A Probs object containing probabilities of each class for classification task.
#         keypoints (Keypoints, optional): A Keypoints object containing detected keypoints for each object.
#         speed (dict): A dictionary of preprocess, inference, and postprocess speeds in milliseconds per image.
#         names (dict): A dictionary of class names.
#         path (str): The path to the image file.
#         _keys (tuple): A tuple of attribute names for non-empty attributes.

# %%
from ultralytics import YOLO
model_path = "./models/region_detection_model.pt"
extract_interesting_regions_ml_model = YOLO(model_path)


def extract_interesting_regions_ml(image):
    results = extract_interesting_regions_ml_model.predict(source=image,imgsz=640,conf=0.25,iou=0.45)
    results = results[0]
    boxes = results.boxes
    classes = boxes.cls
    zipped = list(zip(classes, boxes))
    rectangles = []
    classes = []
    for cls, box in zipped:
        tensor = box.xyxy[0]
        x1 = int(tensor[0].item())
        y1 = int(tensor[1].item())
        x2 = int(tensor[2].item())
        y2 = int(tensor[3].item())
        rectangles.append([[x1,y1],[x2, y2]])
        classes.append(int(cls))
    return rectangles, classes

# %%
input_folders, output_folders = setup_folders("slike_ciste","slike_ciste_custom_ime")

def save_image(src, dest):
    image = cv2.imread(src)
    cv2.imwrite(dest, image)
    pass

num_threads = 5
folders = list(zip(input_folders, output_folders))
for input_folder, output_folder in folders:
    print(f"Folder {input_folder}")
    print("Start clean...")
    s = time()
    images = os.listdir(input_folder)
    threads = []

    for idx, in_image in enumerate(images):
        out_image = f"form_{idx}.jpg"
        image1, image2 = f"{input_folder}/{in_image}", f"{output_folder}/{out_image}"
        print("In: ", image1)
        print("Out: ", image2)
        #extract_interesting_regions_threading(image1, image2)
        #"""
        thread = threading.Thread(target=save_image, args=(image1, image2))
        thread.start()
        threads.append(thread)
        if len(threads) >= num_threads:
            for thread in threads:
                thread.join()
            threads = []
        #"""
    e = time()
    print(f"End clean, time took {e-s}")
# Out:
# Folder ./slike_ciste/FormatA
# Start clean...
# In:  ./slike_ciste/FormatA/30519.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_0.jpg
# In:  ./slike_ciste/FormatA/30520.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_1.jpg
# In:  ./slike_ciste/FormatA/30535.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_2.jpg
# In:  ./slike_ciste/FormatA/30543-denoise-sharpen.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_3.jpg
# In:  ./slike_ciste/FormatA/30706-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_4.jpg
# In:  ./slike_ciste/FormatA/30922-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_5.jpg
# In:  ./slike_ciste/FormatA/30925-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_6.jpg
# In:  ./slike_ciste/FormatA/30926-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_7.jpg
# In:  ./slike_ciste/FormatA/30960-denoise-sharpen.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_8.jpg
# In:  ./slike_ciste/FormatA/30967-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_9.jpg
# In:  ./slike_ciste/FormatA/30969-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_10.jpg
# In:  ./slike_ciste/FormatA/30972-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_11.jpg
# In:  ./slike_ciste/FormatA/30977a-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_12.jpg
# In:  ./slike_ciste/FormatA/31094-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_13.jpg
# In:  ./slike_ciste/FormatA/31131-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_14.jpg
# In:  ./slike_ciste/FormatA/31136-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_15.jpg
# In:  ./slike_ciste/FormatA/31138-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_16.jpg
# In:  ./slike_ciste/FormatA/31139-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_17.jpg
# In:  ./slike_ciste/FormatA/31142-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_18.jpg
# In:  ./slike_ciste/FormatA/31150-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_19.jpg
# In:  ./slike_ciste/FormatA/31190-denoise-sharpen.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_20.jpg
# In:  ./slike_ciste/FormatA/32860-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_21.jpg
# In:  ./slike_ciste/FormatA/32862-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_22.jpg
# In:  ./slike_ciste/FormatA/33021a-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_23.jpg
# In:  ./slike_ciste/FormatA/33021b-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_24.jpg
# In:  ./slike_ciste/FormatA/33238-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_25.jpg
# In:  ./slike_ciste/FormatA/40688-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_26.jpg
# In:  ./slike_ciste/FormatA/50676-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_27.jpg
# In:  ./slike_ciste/FormatA/50677-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_28.jpg
# In:  ./slike_ciste/FormatA/50678-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_29.jpg
# In:  ./slike_ciste/FormatA/50682-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_30.jpg
# In:  ./slike_ciste/FormatA/50684-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_31.jpg
# In:  ./slike_ciste/FormatA/50685-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_32.jpg
# In:  ./slike_ciste/FormatA/50689-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_33.jpg
# In:  ./slike_ciste/FormatA/50690-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_34.jpg
# In:  ./slike_ciste/FormatA/50691-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_35.jpg
# In:  ./slike_ciste/FormatA/51355-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_36.jpg
# In:  ./slike_ciste/FormatA/51356-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_37.jpg
# In:  ./slike_ciste/FormatA/51357-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_38.jpg
# In:  ./slike_ciste/FormatA/51358-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_39.jpg
# In:  ./slike_ciste/FormatA/51359-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_40.jpg
# In:  ./slike_ciste/FormatA/51361-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_41.jpg
# In:  ./slike_ciste/FormatA/51362-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_42.jpg
# In:  ./slike_ciste/FormatA/51363-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_43.jpg
# In:  ./slike_ciste/FormatA/51364-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_44.jpg
# In:  ./slike_ciste/FormatA/51365-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_45.jpg
# In:  ./slike_ciste/FormatA/51374-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_46.jpg
# In:  ./slike_ciste/FormatA/51385-denoise-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_47.jpg
# In:  ./slike_ciste/FormatA/gp 750-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_48.jpg
# In:  ./slike_ciste/FormatA/gp 835-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_49.jpg
# In:  ./slike_ciste/FormatA/gp 838-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_50.jpg
# In:  ./slike_ciste/FormatA/gp 839-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_51.jpg
# In:  ./slike_ciste/FormatA/gp 892-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_52.jpg
# In:  ./slike_ciste/FormatA/gp 982-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_53.jpg
# In:  ./slike_ciste/FormatA/gp1002b-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_54.jpg
# In:  ./slike_ciste/FormatA/gp1025-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_55.jpg
# In:  ./slike_ciste/FormatA/gp1026-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_56.jpg
# In:  ./slike_ciste/FormatA/gp1027-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_57.jpg
# In:  ./slike_ciste/FormatA/gp1028-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_58.jpg
# In:  ./slike_ciste/FormatA/gp1029-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_59.jpg
# In:  ./slike_ciste/FormatA/gp1030-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_60.jpg
# In:  ./slike_ciste/FormatA/gp1031-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_61.jpg
# In:  ./slike_ciste/FormatA/gp1032-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_62.jpg
# In:  ./slike_ciste/FormatA/gp1033-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_63.jpg
# In:  ./slike_ciste/FormatA/gp1034-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_64.jpg
# In:  ./slike_ciste/FormatA/gp1219-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_65.jpg
# In:  ./slike_ciste/FormatA/gp1328-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_66.jpg
# In:  ./slike_ciste/FormatA/gp1329-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_67.jpg
# In:  ./slike_ciste/FormatA/gp1330-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_68.jpg
# In:  ./slike_ciste/FormatA/gp1331-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_69.jpg
# In:  ./slike_ciste/FormatA/gp1332-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_70.jpg
# In:  ./slike_ciste/FormatA/gp1333-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_71.jpg
# In:  ./slike_ciste/FormatA/gp1334-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_72.jpg
# In:  ./slike_ciste/FormatA/gp1335-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_73.jpg
# In:  ./slike_ciste/FormatA/gp1336-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_74.jpg
# In:  ./slike_ciste/FormatA/gp1337-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_75.jpg
# In:  ./slike_ciste/FormatA/gp1338-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_76.jpg
# In:  ./slike_ciste/FormatA/gp1339-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_77.jpg
# In:  ./slike_ciste/FormatA/gp1341b-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_78.jpg
# In:  ./slike_ciste/FormatA/gp1342-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_79.jpg
# In:  ./slike_ciste/FormatA/gp1642-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_80.jpg
# In:  ./slike_ciste/FormatA/gp1648-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_81.jpg
# In:  ./slike_ciste/FormatA/gp1649-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_82.jpg
# In:  ./slike_ciste/FormatA/gp1650-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_83.jpg
# In:  ./slike_ciste/FormatA/gp1651-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_84.jpg
# In:  ./slike_ciste/FormatA/gp1652-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_85.jpg
# In:  ./slike_ciste/FormatA/gp1654-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_86.jpg
# In:  ./slike_ciste/FormatA/gp1656-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_87.jpg
# In:  ./slike_ciste/FormatA/gp1657-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_88.jpg
# In:  ./slike_ciste/FormatA/gp1658-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_89.jpg
# In:  ./slike_ciste/FormatA/gp1658b-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_90.jpg
# In:  ./slike_ciste/FormatA/gp1659-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_91.jpg
# In:  ./slike_ciste/FormatA/gp1660-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_92.jpg
# In:  ./slike_ciste/FormatA/gp1661-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_93.jpg
# In:  ./slike_ciste/FormatA/gp1667-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_94.jpg
# In:  ./slike_ciste/FormatA/gp1669-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_95.jpg
# In:  ./slike_ciste/FormatA/gp1671-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_96.jpg
# In:  ./slike_ciste/FormatA/gp1673-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_97.jpg
# In:  ./slike_ciste/FormatA/gp1674-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_98.jpg
# In:  ./slike_ciste/FormatA/gp1761-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_99.jpg
# In:  ./slike_ciste/FormatA/gp2175-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_100.jpg
# In:  ./slike_ciste/FormatA/gp2176-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_101.jpg
# In:  ./slike_ciste/FormatA/gp2177-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_102.jpg
# In:  ./slike_ciste/FormatA/gp2259-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_103.jpg
# In:  ./slike_ciste/FormatA/gp2260-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_104.jpg
# In:  ./slike_ciste/FormatA/gp2261-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_105.jpg
# In:  ./slike_ciste/FormatA/hcr_31133a-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_106.jpg
# In:  ./slike_ciste/FormatA/hcr_31133b-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_107.jpg
# In:  ./slike_ciste/FormatA/hcr_31144a-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_108.jpg
# In:  ./slike_ciste/FormatA/hcr_31144b-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_109.jpg
# In:  ./slike_ciste/FormatA/un1027-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_110.jpg
# In:  ./slike_ciste/FormatA/un1041a-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_111.jpg
# In:  ./slike_ciste/FormatA/un1041b-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_112.jpg
# In:  ./slike_ciste/FormatA/un1080-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_113.jpg
# In:  ./slike_ciste/FormatA/un1090-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_114.jpg
# In:  ./slike_ciste/FormatA/un1091-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_115.jpg
# In:  ./slike_ciste/FormatA/un1118-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_116.jpg
# In:  ./slike_ciste/FormatA/un1177-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_117.jpg
# In:  ./slike_ciste/FormatA/un1178-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_118.jpg
# In:  ./slike_ciste/FormatA/un1182-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_119.jpg
# In:  ./slike_ciste/FormatA/un1183-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_120.jpg
# In:  ./slike_ciste/FormatA/un1184-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_121.jpg
# In:  ./slike_ciste/FormatA/un1188-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_122.jpg
# In:  ./slike_ciste/FormatA/un1194-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_123.jpg
# In:  ./slike_ciste/FormatA/un1239-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_124.jpg
# In:  ./slike_ciste/FormatA/un1242-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_125.jpg
# In:  ./slike_ciste/FormatA/un1243-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_126.jpg
# In:  ./slike_ciste/FormatA/un1246-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_127.jpg
# In:  ./slike_ciste/FormatA/un1247-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_128.jpg
# In:  ./slike_ciste/FormatA/un1269a-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_129.jpg
# In:  ./slike_ciste/FormatA/un1269b-enhance.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_130.jpg
# In:  ./slike_ciste/FormatA/un1270-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_131.jpg
# In:  ./slike_ciste/FormatA/un1271-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_132.jpg
# In:  ./slike_ciste/FormatA/un1272a-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_133.jpg
# In:  ./slike_ciste/FormatA/un1272b-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_134.jpg
# In:  ./slike_ciste/FormatA/un1274-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_135.jpg
# In:  ./slike_ciste/FormatA/un951-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_136.jpg
# In:  ./slike_ciste/FormatA/zmp111-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_137.jpg
# In:  ./slike_ciste/FormatA/zmp112-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_138.jpg
# In:  ./slike_ciste/FormatA/zmp113-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_139.jpg
# In:  ./slike_ciste/FormatA/zmp114-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_140.jpg
# In:  ./slike_ciste/FormatA/zmp118-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_141.jpg
# In:  ./slike_ciste/FormatA/zmp119-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_142.jpg
# In:  ./slike_ciste/FormatA/zmp121-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_143.jpg
# In:  ./slike_ciste/FormatA/zmp122-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_144.jpg
# In:  ./slike_ciste/FormatA/zmp123-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_145.jpg
# In:  ./slike_ciste/FormatA/zmp124-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_146.jpg
# In:  ./slike_ciste/FormatA/zmp125-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_147.jpg
# In:  ./slike_ciste/FormatA/zmp126-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_148.jpg
# In:  ./slike_ciste/FormatA/zmp127-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_149.jpg
# In:  ./slike_ciste/FormatA/zmp128-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_150.jpg
# In:  ./slike_ciste/FormatA/zmp129-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_151.jpg
# In:  ./slike_ciste/FormatA/zmp130-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_152.jpg
# In:  ./slike_ciste/FormatA/zmp131-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_153.jpg
# In:  ./slike_ciste/FormatA/zmp132-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_154.jpg
# In:  ./slike_ciste/FormatA/zmp133-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_155.jpg
# In:  ./slike_ciste/FormatA/zmp134-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_156.jpg
# In:  ./slike_ciste/FormatA/zmp135-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_157.jpg
# In:  ./slike_ciste/FormatA/zmp136-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_158.jpg
# In:  ./slike_ciste/FormatA/zmp137-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_159.jpg
# In:  ./slike_ciste/FormatA/zmp138-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_160.jpg
# In:  ./slike_ciste/FormatA/zmp139-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_161.jpg
# In:  ./slike_ciste/FormatA/zmp140-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_162.jpg
# In:  ./slike_ciste/FormatA/zmp141-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_163.jpg
# In:  ./slike_ciste/FormatA/zmp142-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_164.jpg
# In:  ./slike_ciste/FormatA/zmp144-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_165.jpg
# In:  ./slike_ciste/FormatA/zmp146-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_166.jpg
# In:  ./slike_ciste/FormatA/zmp147-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_167.jpg
# In:  ./slike_ciste/FormatA/zmp149-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_168.jpg
# In:  ./slike_ciste/FormatA/zmp150-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_169.jpg
# In:  ./slike_ciste/FormatA/zmp151-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_170.jpg
# In:  ./slike_ciste/FormatA/zmp152-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_171.jpg
# In:  ./slike_ciste/FormatA/zmp153-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_172.jpg
# In:  ./slike_ciste/FormatA/zmp154-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_173.jpg
# In:  ./slike_ciste/FormatA/zmp155-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_174.jpg
# In:  ./slike_ciste/FormatA/zmp156-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_175.jpg
# In:  ./slike_ciste/FormatA/zmp157-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_176.jpg
# In:  ./slike_ciste/FormatA/zmp158-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_177.jpg
# In:  ./slike_ciste/FormatA/zmp159-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_178.jpg
# In:  ./slike_ciste/FormatA/zmp160-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_179.jpg
# In:  ./slike_ciste/FormatA/zmp161-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_180.jpg
# In:  ./slike_ciste/FormatA/zmp162-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_181.jpg
# In:  ./slike_ciste/FormatA/zmp163-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_182.jpg
# In:  ./slike_ciste/FormatA/zmp164-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_183.jpg
# In:  ./slike_ciste/FormatA/zmp165-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_184.jpg
# In:  ./slike_ciste/FormatA/zmp166-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_185.jpg
# In:  ./slike_ciste/FormatA/zmp167-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_186.jpg
# In:  ./slike_ciste/FormatA/zmp168-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_187.jpg
# In:  ./slike_ciste/FormatA/zmp169-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_188.jpg
# In:  ./slike_ciste/FormatA/zmp170-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_189.jpg
# In:  ./slike_ciste/FormatA/zmp171-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_190.jpg
# In:  ./slike_ciste/FormatA/zmp172-denoise.jpg
# Out:  ./slike_ciste_custom_ime/FormatA/form_191.jpg
# End clean, time took 26.45933961868286
# Folder ./slike_ciste/FormatB
# Start clean...
# In:  ./slike_ciste/FormatB/31146a.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_0.jpg
# In:  ./slike_ciste/FormatB/31146b.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_1.jpg
# In:  ./slike_ciste/FormatB/31153.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_2.jpg
# In:  ./slike_ciste/FormatB/31163a.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_3.jpg
# In:  ./slike_ciste/FormatB/31164.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_4.jpg
# In:  ./slike_ciste/FormatB/31165.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_5.jpg
# In:  ./slike_ciste/FormatB/31167.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_6.jpg
# In:  ./slike_ciste/FormatB/31169a.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_7.jpg
# In:  ./slike_ciste/FormatB/31169b.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_8.jpg
# In:  ./slike_ciste/FormatB/31171.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_9.jpg
# In:  ./slike_ciste/FormatB/hcr_31157a.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_10.jpg
# In:  ./slike_ciste/FormatB/hcr_31157b.jpg
# Out:  ./slike_ciste_custom_ime/FormatB/form_11.jpg
# End clean, time took 1.2486135959625244

# %%
input_folders, output_folders = setup_folders("slike_ciste_custom_ime","jpg_minski_zapisnici_clean_ml_regions_2")

# %%
from time import time
import threading
import cv2
from utils.extract_regions import extract_rectangle

def extract_interesting_regions_threading(src: str, dest: str):
    empty, dest, ext = dest.split('.')
    image = cv2.imread(src)
    regions, classes = extract_interesting_regions_ml(image)
    regions = [extract_rectangle(image, region[0], region[1], wiggle_room=15) for region in regions]
    regions = list(zip(classes, regions))
    for i, region in regions:
        a = f".{dest}_{i}.{ext}"
        if len(region) > 0:
            written = cv2.imwrite(a, region)
            print("Is written", written)

num_threads = 5
folders = list(zip(input_folders, output_folders))
for input_folder, output_folder in folders:
    print(f"Folder {input_folder}")
    print("Start clean...")
    s = time()
    images = os.listdir(input_folder)
    threads = []

    for in_image in images:
        image1, image2 = f"{input_folder}/{in_image}", f"{output_folder}/{in_image}"
        print("In: ", image1)
        print("Out: ", image2)
        #extract_interesting_regions_threading(image1, image2)
        #"""
        thread = threading.Thread(target=extract_interesting_regions_threading, args=(image1, image2))
        thread.start()
        threads.append(thread)
        if len(threads) >= num_threads:
            for thread in threads:
                thread.join()
            threads = []
        #"""
    e = time()
    print(f"End clean, time took {e-s}")
# Out:
# Folder ./slike_ciste_custom_ime/FormatA
# Start clean...
# In:  ./slike_ciste_custom_ime/FormatA/form_0.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_0.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_1.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_1.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_10.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_10.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_100.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_100.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_101.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_101.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 155.8ms
# Speed: 31.0ms preprocess, 155.8ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 171.0ms
# Speed: 12.1ms preprocess, 171.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 196.0ms
# Is written True
# Speed: 10.4ms preprocess, 196.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 194.6ms
# Speed: 11.3ms preprocess, 194.6ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 157.8ms
# Speed: 16.5ms preprocess, 157.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_102.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_102.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_103.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_103.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_104.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_104.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_105.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_105.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_106.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_106.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 126.1ms
# Speed: 26.8ms preprocess, 126.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 145.7ms
# Speed: 8.1ms preprocess, 145.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 166.2ms
# Speed: 10.1ms preprocess, 166.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 149.7ms
# Speed: 8.5ms preprocess, 149.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x448 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 132.0ms
# Speed: 16.6ms preprocess, 132.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_107.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_107.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_108.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_108.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_109.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_109.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_11.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_11.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_110.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_110.jpg
#
#
#
#
#
# 0: 640x416 1 record, 1 map, 1 detailed information, 126.1ms
# Speed: 19.8ms preprocess, 126.1ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 416)
# Is written True
# Is written True
# Is written True
# 0: 640x448 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 120.2ms
# Speed: 10.1ms preprocess, 120.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x448 1 record, 3 maps, 142.3ms
# Speed: 2.0ms preprocess, 142.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x448 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 138.2ms
# Speed: 10.1ms preprocess, 138.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 144.2ms
# Speed: 9.4ms preprocess, 144.2ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_111.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_111.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_112.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_112.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_113.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_113.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_114.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_114.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_115.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_115.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 145.9ms
# Speed: 10.2ms preprocess, 145.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 123.4ms
# Speed: 8.1ms preprocess, 123.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 155.7ms
# Speed: 16.2ms preprocess, 155.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 167.1ms
# Speed: 8.0ms preprocess, 167.1ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 608x640 (no detections), 175.8ms
# Speed: 9.1ms preprocess, 175.8ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_116.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_116.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_117.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_117.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_118.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_118.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_119.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_119.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_12.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_12.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 131.8ms
# Speed: 15.5ms preprocess, 131.8ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 147.6ms
# Speed: 4.3ms preprocess, 147.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 213.3ms
# Speed: 7.9ms preprocess, 213.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 168.2ms
# Speed: 8.0ms preprocess, 168.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 141.0ms
# Speed: 9.5ms preprocess, 141.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_120.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_120.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_121.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_121.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_122.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_122.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_123.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_123.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_124.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_124.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 125.8ms
# Speed: 8.1ms preprocess, 125.8ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 156.9ms
# Speed: 0.0ms preprocess, 156.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 157.0ms
# Speed: 8.1ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 133.1ms
# Speed: 8.1ms preprocess, 133.1ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is writtenIs written True
#  True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 149.1ms
# Speed: 10.2ms preprocess, 149.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_125.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_125.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_126.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_126.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_127.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_127.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_128.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_128.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_129.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_129.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 129.0ms
# Speed: 28.8ms preprocess, 129.0ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 141.5ms
# Speed: 10.2ms preprocess, 141.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 158.6ms
# Speed: 7.9ms preprocess, 158.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 221.5ms
# Speed: 11.7ms preprocess, 221.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 137.8ms
# Speed: 8.1ms preprocess, 137.8ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_13.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_13.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_130.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_130.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_131.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_131.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_132.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_132.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_133.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_133.jpg
#
#
#
#
#
# 0: 640x448 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 148.5ms
# Speed: 15.3ms preprocess, 148.5ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 448)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 142.6ms
# Speed: 9.4ms preprocess, 142.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 165.3ms
# Speed: 5.6ms preprocess, 165.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 148.3ms
# Speed: 10.4ms preprocess, 148.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x608 2 records, 1 map, 1 legend, 163.2ms
# Speed: 10.0ms preprocess, 163.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_134.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_134.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_135.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_135.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_136.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_136.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_137.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_137.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_138.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_138.jpg
#
#
#
#
#
# 0: 640x544 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 150.7ms
# Speed: 21.2ms preprocess, 150.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 544)
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 137.6ms
# Speed: 4.7ms preprocess, 137.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 448x640 1 overhead, 3 records, 1 map, 145.5ms
# Speed: 10.3ms preprocess, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 181.9ms
# Speed: 10.2ms preprocess, 181.9ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 137.7ms
# Speed: 10.1ms preprocess, 137.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_139.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_139.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_14.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_14.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_140.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_140.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_141.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_141.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_142.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_142.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 167.6ms
# Speed: 10.2ms preprocess, 167.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 128.6ms
# Speed: 10.1ms preprocess, 128.6ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 145.3ms
# Speed: 10.1ms preprocess, 145.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 142.7ms
# Speed: 11.1ms preprocess, 142.7ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 145.6ms
# Speed: 9.3ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_143.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_143.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_144.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_144.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_145.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_145.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_146.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_146.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_147.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_147.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 145.8ms
# Speed: 26.5ms preprocess, 145.8ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 151.0ms
# Speed: 10.1ms preprocess, 151.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 153.7ms
# Speed: 10.1ms preprocess, 153.7ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 150.2ms
# Speed: 8.3ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 150.2ms
# Speed: 10.1ms preprocess, 150.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_148.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_148.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_149.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_149.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_15.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_15.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_150.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_150.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_151.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_151.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 139.0ms
# Speed: 21.9ms preprocess, 139.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 157.8ms
# Speed: 6.3ms preprocess, 157.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 155.6ms
# Speed: 10.1ms preprocess, 155.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 154.9ms
# Speed: 10.1ms preprocess, 154.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 145.4ms
# Speed: 10.1ms preprocess, 145.4ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_152.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_152.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_153.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_153.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_154.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_154.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_155.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_155.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_156.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_156.jpg
#
#
#
#
#
# 0: 640x512 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 146.1ms
# Speed: 16.7ms preprocess, 146.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 136.6ms
# Speed: 2.1ms preprocess, 136.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 151.4ms
# Speed: 10.2ms preprocess, 151.4ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 162.8ms
# Speed: 8.0ms preprocess, 162.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 158.3ms
# Speed: 10.1ms preprocess, 158.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_157.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_157.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_158.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_158.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_159.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_159.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_16.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_16.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_160.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_160.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 143.4ms
# Speed: 15.6ms preprocess, 143.4ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 134.5ms
# Speed: 10.2ms preprocess, 134.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 149.5ms
# Speed: 10.1ms preprocess, 149.5ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 136.9ms
# Speed: 11.5ms preprocess, 136.9ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 150.7ms
# Speed: 6.1ms preprocess, 150.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_161.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_161.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_162.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_162.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_163.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_163.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_164.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_164.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_165.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_165.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 159.7ms
# Speed: 11.7ms preprocess, 159.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 150.3ms
# Speed: 18.4ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 160.6ms
# Speed: 10.1ms preprocess, 160.6ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 154.1ms
# Speed: 8.0ms preprocess, 154.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 151.7ms
# Speed: 10.1ms preprocess, 151.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_166.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_166.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_167.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_167.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_168.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_168.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_169.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_169.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_17.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_17.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 152.9ms
# Speed: 18.4ms preprocess, 152.9ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 169.9ms
# Speed: 10.3ms preprocess, 169.9ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 151.1ms
# Speed: 10.1ms preprocess, 151.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 150.6ms
# Speed: 14.4ms preprocess, 150.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 139.5ms
# Speed: 10.1ms preprocess, 139.5ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_170.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_170.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_171.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_171.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_172.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_172.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_173.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_173.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_174.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_174.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 153.1ms
# Speed: 8.1ms preprocess, 153.1ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 228.7ms
# Speed: 8.0ms preprocess, 228.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 150.2ms
# Speed: 10.2ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 158.3ms
# Speed: 10.1ms preprocess, 158.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 181.1ms
# Speed: 7.7ms preprocess, 181.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_175.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_175.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_176.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_176.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_177.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_177.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_178.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_178.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_179.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_179.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 128.8ms
# Speed: 30.4ms preprocess, 128.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 159.3ms
# Speed: 0.0ms preprocess, 159.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 139.7ms
# Speed: 10.1ms preprocess, 139.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 147.0ms
# Speed: 9.9ms preprocess, 147.0ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 154.3ms
# Speed: 12.6ms preprocess, 154.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_18.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_18.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_180.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_180.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_181.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_181.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_182.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_182.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_183.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_183.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 121.6ms
# Speed: 37.4ms preprocess, 121.6ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 132.1ms
# Speed: 10.1ms preprocess, 132.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 162.4ms
# Speed: 2.1ms preprocess, 162.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 147.8ms
# ...
# Speed: 4.1ms preprocess, 162.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 150.3ms
# Speed: 10.2ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 160.2ms
# Speed: 6.4ms preprocess, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_84.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_84.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_85.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_85.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_86.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_86.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_87.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_87.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_88.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_88.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 143.4ms
# Speed: 10.6ms preprocess, 143.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 139.3ms
# Speed: 2.1ms preprocess, 139.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 156.5ms
# Speed: 10.2ms preprocess, 156.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 140.5ms
# Speed: 12.2ms preprocess, 140.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 161.4ms
# Speed: 10.1ms preprocess, 161.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_89.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_89.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_9.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_9.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_90.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_90.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_91.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_91.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_92.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_92.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 122.6ms
# Speed: 10.2ms preprocess, 122.6ms inference, 12.3ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 137.8ms
# Speed: 10.1ms preprocess, 137.8ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 155.1ms
# Speed: 10.1ms preprocess, 155.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 162.7ms
# Speed: 15.3ms preprocess, 162.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 137.3ms
# Speed: 10.0ms preprocess, 137.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_93.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_93.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_94.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_94.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_95.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_95.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_96.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_96.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_97.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_97.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 149.4ms
# Speed: 20.3ms preprocess, 149.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 164.1ms
# Speed: 3.6ms preprocess, 164.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 153.0ms
# Speed: 8.1ms preprocess, 153.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 147.5ms
# Speed: 10.1ms preprocess, 147.5ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 146.6ms
# Speed: 7.6ms preprocess, 146.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatA/form_98.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_98.jpg
# In:  ./slike_ciste_custom_ime/FormatA/form_99.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatA/form_99.jpg
# End clean, time took 51.12067532539368
# Folder ./slike_ciste_custom_ime/FormatB
# Start clean...
# In:  ./slike_ciste_custom_ime/FormatB/form_0.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_0.jpg
# In:  ./slike_ciste_custom_ime/FormatB/form_1.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_1.jpg
# In:  ./slike_ciste_custom_ime/FormatB/form_10.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_10.jpg
# In:  ./slike_ciste_custom_ime/FormatB/form_11.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_11.jpg
# In:  ./slike_ciste_custom_ime/FormatB/form_2.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_2.jpg
#
#
#
#
#
#
#
# 0: 640x448 2 records, 1 map, 1 legend, 168.3ms
# Speed: 15.2ms preprocess, 168.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 480x640 1 overhead, 1 record, 1 map, 1 detailed information, 1 unit record, 1 demainer information, 138.5ms
# Speed: 10.1ms preprocess, 138.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 141.6ms
# Speed: 8.0ms preprocess, 141.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 132.5ms
# Speed: 6.7ms preprocess, 132.5ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 224.6ms
# Speed: 9.6ms preprocess, 224.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x416 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 141.5ms
# Speed: 6.8ms preprocess, 141.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 416)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 147.2ms
# Speed: 8.2ms preprocess, 147.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatB/form_3.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_3.jpg
# In:  ./slike_ciste_custom_ime/FormatB/form_4.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_4.jpg
# In:  ./slike_ciste_custom_ime/FormatB/form_5.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_5.jpg
# In:  ./slike_ciste_custom_ime/FormatB/form_6.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_6.jpg
# In:  ./slike_ciste_custom_ime/FormatB/form_7.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_7.jpg
#
#
#
#
#
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 155.0ms
# Speed: 10.2ms preprocess, 155.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 2 legends, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 134.5ms
# Speed: 10.1ms preprocess, 134.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 164.0ms
# Speed: 16.7ms preprocess, 164.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 150.0ms
# Speed: 5.6ms preprocess, 150.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is writtenIs written True
#  True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 135.1ms
# Is written True
# Speed: 10.1ms preprocess, 135.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./slike_ciste_custom_ime/FormatB/form_8.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_8.jpg
# In:  ./slike_ciste_custom_ime/FormatB/form_9.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions_2/FormatB/form_9.jpg
# End clean, time took 3.0040085315704346
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 229.2ms
# Speed: 10.2ms preprocess, 229.2ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 2 structures, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 143.1ms
# Speed: 11.8ms preprocess, 143.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True

# %% [markdown]
# The results with the trained model is much better in all cases, so it will be used for further implementations

# %%
import os
output = "./jpg_minski_zapisnici_clean_ml_regions_separated_2"
if not os.path.isdir(f"./{output}"):
    os.mkdir(f"./{output}")
outputs = []
for i in range(9):
    output = f"./jpg_minski_zapisnici_clean_ml_regions_separated_2/reg_{i}"
    if not os.path.isdir(f"./{output}"):
        os.mkdir(f"./{output}")
    outputs.append(output)

# %% [markdown]
# From now on only Format A will be considered as it is the one that has latin text

# %%
import cv2
input = "./jpg_minski_zapisnici_clean_ml_regions_2/FormatA"
files = os.listdir(input)
for i, out in enumerate(outputs):
    suffix = f"_{i}.jpg"
    for file in files:
        if file.endswith(suffix):
            img = cv2.imread(f"{input}/{file}")
            cv2.imwrite(f"{out}/{file}", img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import cv2
#       2 input = "./jpg_minski_zapisnici_clean_ml_regions_2/FormatA"
# ----> 3 files = os.listdir(input)
#       4 for i, out in enumerate(outputs):
#       5     suffix = f"_{i}.jpg"
#
# NameError: name 'os' is not defined

# %%
import os
from utils.label_generator import (
    generate_word_labels,
    generate_line_labels,
    generate_region_labels
)

path = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_5_PASCALVOC_LABELE"
labels = os.listdir(path)
labels = [l for l in labels if l.endswith(".xml")]

generate_word_labels(path, labels)
generate_line_labels(path, labels)
#generate_region_labels(path, labels)
#

# %%
#region 0
import os
from utils.label_generator import (
    generate_word_labels,
    generate_line_labels,
    generate_region_labels
)

path = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_0_PASCALVOC_LABELE"
labels = os.listdir(path)
labels = [l for l in labels if l.endswith(".xml")]

generate_word_labels(path, labels)

# %%
import os
minski_zapisnici = "./minski_zapisnici_only_word_reg5"
if not os.path.isdir(minski_zapisnici):
    os.mkdir(minski_zapisnici)
outputs = []
for i in ["word", "line"]:
    output = f"./{minski_zapisnici}/{i}"
    if not os.path.isdir(f"./{output}"):
        os.mkdir(f"./{output}")

    outputs.append(output)

# %%
from utils.extract_regions import extract_rectangle
import cv2
import os

line_labels_5 = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_5_PASCALVOC_LABELE/line_labels.txt"
word_labels_5 = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_5_PASCALVOC_LABELE/word_labels.txt"
word_labels = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_0_PASCALVOC_LABELE/word_labels.txt"

path1 = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_5_PASCALVOC_LABELE"
path2 = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_0_PASCALVOC_LABELE"


labels = os.listdir(path)
labels = [l for l in labels if l.endswith(".xml")]

def generate_line_images(line_labels, src, dest):
    with open(line_labels, "r", encoding="utf8") as read:
        with open(f"{dest}/line.txt", "w", encoding="utf8") as write:
            while line := read.readline():
                line = line.removesuffix("\n").split("|")
                filename, l_idx, w, h, l_x_min, l_y_min, l_x_max, l_y_max, text = line
                img = cv2.imread(f"{src}/{filename}")
                line_img = extract_rectangle(img, [int(l_x_min), int(l_y_min)], [int(l_x_max), int(l_y_max)])
                filename = filename.removesuffix(".jpg")
                img_path = f"{dest}/line/{filename}_{l_idx}.jpg"
                try:
                    cv2.imwrite(img_path, line_img)
                    line[0] = f"{filename}_{l_idx}.jpg"
                    write.write(f"{'|'.join(line)}\n")
                except Exception as e:
                    print(e)

def generate_word_images(word_labels, src, dest):
    with open(word_labels, "r", encoding="utf8") as read:
        with open(f"{dest}/word.txt", "w", encoding="utf8") as write:
            while line := read.readline():
                line = line.removesuffix("\n").split("|")
                filename, word_idx, w, h, xmin, ymin, xmax, ymax, word = line
                img = cv2.imread(f"{src}/{filename}")
                if img is None:
                    print(f"{src}/{filename}")
                word_img = extract_rectangle(img, [int(xmin), int(ymin)], [int(xmax), int(ymax)])
                filename = filename.removesuffix(".jpg")
                img_path = f"{dest}/word/{filename}_{word_idx}.jpg"
                try:
                    cv2.imwrite(img_path, word_img)
                    line[0] = f"{filename}_{word_idx}.jpg"
                    write.write(f"{'|'.join(line)}\n")
                except Exception as e:
                    print(e)


generate_line_images(line_labels_5,path1,"./a/1")
generate_word_images(word_labels_5,path1,"./a/1")
generate_word_images(word_labels,path2,"./a/2")
# Out:
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
generate_line_images("./test_dataset_1/line_labels.txt", "./test_dataset_1/regions", "./test_dataset_1/labels_l")
# Out:
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
generate_word_images("./test_dataset_1/word_labels.txt", "./test_dataset_1/regions", "./test_dataset_1/labels_w")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 generate_word_images("./test_dataset_1/word_labels.txt", "./test_dataset_1/regions", "./test_dataset_1/labels_w")
#
# Cell In[5], line 30, in generate_word_images(word_labels, src, dest)
#      28 def generate_word_images(word_labels, src, dest):
#      29     with open(word_labels, "r", encoding="utf8") as read:
# ---> 30         with open(f"{dest}/word.txt", "w", encoding="utf8") as write:
#      31             while line := read.readline():
#      32                 line = line.removesuffix("\n").split("|")
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './test_dataset_1/labels_w/word.txt'

# %%
generate_line_images(line_labels, path, )

# %%
#region 0
word_labels = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_0_PASCALVOC_LABELE/word_labels.txt"

path = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_0_PASCALVOC_LABELE"
minski_zapisnici = "./minski_zapisnici_0"
if not os.path.isdir(minski_zapisnici):
    os.mkdir(minski_zapisnici)

minski_zapisnici1 = "./minski_zapisnici_0/word"
if not os.path.isdir(minski_zapisnici1):
    os.mkdir(minski_zapisnici1)

generate_word_images(word_labels,path,minski_zapisnici)
# Out:
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
from sklearn.model_selection import train_test_split
import os


def split_train_set(src_txt: str, out: str, train_size=0.7, val_size=0.2, test_size=0.1, random_state=None):
    assert abs(train_size+val_size+test_size-1.0) < 1e-5, "Train, validation, and test sizes must sum to 1.0"
    elements = []
    with open(src_txt, "r", encoding="utf8") as read:
        while line := read.readline(): 
            elements.append(line)

    if not elements:
        return 0,0,0

    train_val_data, test_data = train_test_split(elements, test_size=test_size, random_state=random_state)
    val_relative_size = val_size / (train_size + val_size)
    train_data, val_data = train_test_split(train_val_data, test_size=val_relative_size, random_state=random_state)
    with open(f"{out}/train.txt", "w", encoding="utf8") as train:
        for el in train_data:
            train.write(el)

    with open(f"{out}/test.txt", "w", encoding="utf8") as test:
        for el in test_data:
            test.write(el)

    with open(f"{out}/val.txt", "w", encoding="utf8") as val:
        for el in val_data:
            val.write(el)

    return len(train_data), len(val_data), len(test_data)


"""
data = "./htr_data/v8/ml_word_data"
if not os.path.isdir(data):
    os.mkdir(data)

r = split_train_set("./htr_data/v8/word.txt", data)
print(r)
print(sum(r))
"""
"""
data = "./minski_zapisnici/ml_word_data"
if not os.path.isdir(data):
    os.mkdir(data)

r = split_train_set("./minski_zapisnici/word.txt", data)
print(r)
"""
# Out:
# '\ndata = "./minski_zapisnici/ml_word_data"\nif not os.path.isdir(data):\n    os.mkdir(data)\n\nr = split_train_set("./minski_zapisnici/word.txt", data)\nprint(r)\n'

# %%
# Out:
# 5161

# %%
base = "./htr_data/v6"

t = f"{base}/word"

ff = list(os.listdir(t))

print(len(ff))
out = []

with open(f"{base}/word.txt", "r", encoding="utf8") as rf:
    with open(f"{base}/word_unique.txt", "w", encoding="utf8") as wf:
        while line := rf.readline():
            line = line.split("|")
            name = line[0]

            if name in ff:
                ff.remove(name)
                wf.write(f"{'|'.join(line)}")
            else: out.append(name)

print(len(out))
# Out:
# 5529
# 92

# %%
t = "./htr_data/v5/line"

ff = list(os.listdir(t))


with open("./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/a.txt", "r", encoding="utf8") as rf:
    with open("./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/aa.txt", "w", encoding="utf8") as wf:
        while line := rf.readline():
            line = line.split("|")
            name = line[0]

            if name in ff:
                ff.remove(name)
                wf.write(f"{'|'.join(line)}")
            else: out.append(name)

# %%
import os
from shutil import copyfile

imgs = [i for i in os.listdir("./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_0_PASCALVOC_LABELE") if i.endswith(".jpg")]
a = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_0_PASCALVOC_LABELE"

for i in imgs:
    copyfile(f"{a}/{i}", f"./htr_data/v2/line/{i}")

# %%
import os
from utils.pascal_voc_to_yolo import pascalVOC2yolo

path = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_5_PASCALVOC_LABELE"

labels = os.listdir(path)
labels = [l for l in labels if l.endswith(".xml")]

for l in labels:
    pascalVOC2yolo(l.removesuffix(".xml"), path)

# %%
import os
path = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_5_PASCALVOC_LABELE"

labels = os.listdir(path)
labels = [l for l in labels if l.endswith(".xml")]

minski_zapisnici = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI_YOLO"
if not os.path.isdir(minski_zapisnici):
    os.mkdir(minski_zapisnici)

outputs = []
for i in ["img", "lbl"]:
    output = f"{minski_zapisnici}/{i}"
    if not os.path.isdir(f"./{output}"):
        os.mkdir(f"./{output}")

    outputs.append(output)

import shutil 
for l in labels:
    l = l.removesuffix(".xml")
    jpg_src = f"{path}/{l}.jpg"
    jpg_dest = f"{outputs[0]}/{l}.jpg"

    txt_src = f"{path}/{l}.txt"
    txt_dest = f"{outputs[1]}/{l}.txt"

    shutil.copyfile(jpg_src, jpg_dest)
    shutil.copyfile(txt_src, txt_dest)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       2 path = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_5_PASCALVOC_LABELE_FULL"
# ----> 4 labels = os.listdir(path)
#       5 labels = [l for l in labels if l.endswith(".xml")]
#       7 minski_zapisnici = "./MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI_YOLO"
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './MINSKI_ZAPISNICI_IMENOVANI_REGIJE_DOKUMENTI/REGIJA_5_PASCALVOC_LABELE_FULL'

# %%
import cv2
from pipeline.handwritten_text_recognition import ExtractText


def build_ds(out_file: str, img_path: str, lbl_file_path: str):
    print("Start building ds", out_file)
    extract_text = ExtractText()
    with open(out_file, "w", encoding="utf8") as ds_file:
        with open(lbl_file_path, "r", encoding="utf8") as lbl_file:
            while line := lbl_file.readline():
                line = line.split("|")
                img_name = line[0]
                lbl = line[-1].removesuffix("\n")
                img = f"{img_path}/{img_name}"
                text = extract_text.execute(img)[0][0]
                ds_file.write(f'"{text}","{lbl}"\n')
    print("Finish building ds", out_file)


build_ds("./llm_ds_test.csv", "./mine_logs2/line", "./mine_logs2/ml_line_data/test.txt")
build_ds(
    "./llm_ds_train.csv", "./mine_logs2/line", "./mine_logs2/ml_line_data/train.txt"
)
build_ds("./llm_ds_val.csv", "./mine_logs2/line", "./mine_logs2/ml_line_data/val.txt")
# Out:
# Start building ds ./llm_ds_test.csv
# Finish building ds ./llm_ds_test.csv
# Start building ds ./llm_ds_train.csv
# Finish building ds ./llm_ds_train.csv
# Start building ds ./llm_ds_val.csv
# Finish building ds ./llm_ds_val.csv

# %%
with open("./llm_ds.csv", "r", encoding="utf8") as rf:
    with open("./llm_lama2_ds.csv", "w", encoding="utf8") as wf:
        while line := rf.readline():
            line = line.split("\",\"")
            _in = line[0].removeprefix("\"")
            out = line[1].removesuffix("\"\n")
            text = f"<s>[INST]:Prepravi sljedeći tekst u smislenu i gramatički tačnu rečenicu: {_in}[/INST]{out}</s>\n"
            wf.write(text)

# %%
d = {
     "features": [
        {
            "feature_idx": 0,
            "name": "text",
            "type": {
                "dtype": "string",
                "_type": "Value"
            }
        }
    ]
}
rows = []
with open("./llm_lama2_ds.csv", "r", encoding="utf8") as rf:
    idx = 0
    while row := rf.readline():
        rows.append({
            "row_idx": idx,
            "text": row,
            "truncated_cells": []
        })
        idx += 1


d["text"] = rows

import json
with open("./llm_lama2_ds.json", "w", ) as wf:
    wf.write(json.dumps(d))

# %%
with open("./llm_lama2_ds.csv", "r", encoding="utf8") as rf:
    idx = 0
    with open("./llm_lama2_ds1.json", "w", ) as wf:
        while row := rf.readline():
            a = {"text": row, "idx": idx}
            wf.write(f"{json.dumps(a)}\n")
            idx += 1

# %%
a = ["ds/llm_ds_test.csv", "ds/llm_ds_train.csv", "ds/llm_ds_val.csv" ]

with open("../ds/llm_ds_faulty.csv", "w", encoding="utf8") as wf:
    for i in a:
        with open(f"../{i}", "r", encoding="utf8") as rf:
            while line:= rf.readline():
                line = line.split("\",\"")
                det = line[0].removeprefix("\"")
                lbl = line[1].removesuffix("\"\n")
                if det != lbl:
                    wf.write(f'"{det}","{lbl}"\n')

# %%
import os

imgs = "./test_dataset_1/regions"


names_a = set()

with open("./test_dataset_1/word_labels.txt", "r", encoding="utf8") as rf:
    while l := rf.readline():
        l = l.removesuffix("\n").split("|")
        n = l[0]
        names_a.add(n)


names_b = set(os.listdir(imgs))


missing = names_b.difference(names_a)

print(len(names_a))
print(len(names_b))
print(len(missing))


for i in missing:
    os.remove(f"{imgs}/{i}")
# Out:
# 303
# 366
# 63

# %%
from sklearn.model_selection import train_test_split


regions = [i.removesuffix(".jpg") for i in os.listdir("./test_dataset_1/regions")]

words = []
with open("./test_dataset_1/word_labels.txt", "r", encoding="utf8") as rf:
    while w:=rf.readline():
        words.append(w.split("|")[0].removesuffix(".jpg"))
reg_histogram = list(sorted([(r, len([i for i in words if i.startswith(r)])) for r in regions], key= lambda el: el[1], reverse=True))

# %%
total_words = len(words)
train_target_words = total_words * 0.7
val_target_words = total_words * 0.2
test_target_words = total_words * 0.1

print(
    int(train_target_words),
    int(val_target_words),
    int(test_target_words)+1)
# Out:
# 3935 1124 563

# %%
train_set, val_set, test_set = [], [], []
train_words, val_words, test_words = 0, 0, 0

for image_path, num_words in reg_histogram:
    if train_words + num_words <= train_target_words:
        train_set.append(image_path)
        train_words += num_words
    elif val_words + num_words <= val_target_words:
        val_set.append(image_path)
        val_words += num_words
    else:
        test_set.append(image_path)
        test_words += num_words

# %%
print(f"Train set: {len(train_set)} images, {train_words} words")
print(f"Validation set: {len(val_set)} images, {val_words} words")
print(f"Test set: {len(test_set)} images, {test_words} words")
# Out:
# Train set: 97 images, 3935 words
# Validation set: 64 images, 1124 words
# Test set: 142 images, 563 words

# %%
with open("./test_dataset_1/regions_sets/train_set.txt", "w") as wf:
    for i in train_set:
        wf.write(f"{i}\n")

with open("./test_dataset_1/regions_sets/val_set.txt", "w") as wf:
    for i in val_set:
        wf.write(f"{i}\n")

with open("./test_dataset_1/regions_sets/test_set.txt", "w") as wf:
    for i in test_set:
        wf.write(f"{i}\n")

# %%
wl = None
with open("./test_dataset_1/word_labels.txt", "r", encoding="utf8") as r:
    wl=r.readlines()

ll = None
with open("./test_dataset_1/line_labels.txt", "r", encoding="utf8") as r:
    ll=r.readlines()


def write(check, file_write_to, lbl):
    with open(file_write_to, "w", encoding="utf8") as wf:
        wf.writelines([l for c in check for l in lbl if l.startswith(c)])
        



write(train_set, "./test_dataset_1/word_ttv/train.txt", wl)
write(val_set, "./test_dataset_1/word_ttv/val.txt", wl)
write(test_set, "./test_dataset_1/word_ttv/test.txt", wl)


write(train_set, "./test_dataset_1/line_ttv/train.txt", ll)
write(val_set, "./test_dataset_1/line_ttv/val.txt", ll)
write(test_set, "./test_dataset_1/line_ttv/test.txt", ll)

# %% [markdown]
# # Kako se ds napravio
#
# 1. kreirani datasetovi koji medjusobno nemaju istu raspodjelu slika
#     a. model treniran na linijama (recenicama)
#     b. model treniran samo na rijecima (ciframa)
# 2. uporedjeni rezultati tih modela
# 3. Odabrani najbolji rezultati
# 4. Podjeljen dataset na tran, val, test tako da se moze trenirati model nad istim podacima s istom raspodjelom

# %%
lines = None
with open("./test_dataset_1/a.txt", "r", encoding="utf8") as rf:
    lines = rf.readlines()

words = None
with open("./test_dataset_1/b.txt", "r", encoding="utf8") as rf:
    words = rf.readlines()

test = None
with open("./test_dataset_1/region_sets/test_set.txt", "r") as rf:
    test = rf.readlines()


val = None
with open("./test_dataset_1/region_sets/val_set.txt", "r") as rf:
    val = rf.readlines()


train = None
with open("./test_dataset_1/region_sets/train_set.txt", "r") as rf:
    train = rf.readlines()


w = {
    "train": [i for i in words for j in train if i.startswith(j.removesuffix("\n"))],
    "test": [i for i in words for j in test if i.startswith(j.removesuffix("\n"))],
    "val": [i for i in words for j in val if i.startswith(j.removesuffix("\n"))],
}

l = {
    "train": [i for i in lines for j in train if i.startswith(j.removesuffix("\n"))],
    "test": [i for i in lines for j in test if i.startswith(j.removesuffix("\n"))],
    "val": [i for i in lines for j in val if i.startswith(j.removesuffix("\n"))],
}


for key, val in l.items():
    with open(f"./test_dataset_1/line_1/{key}.txt", "w", encoding="utf8") as f:
        f.writelines(val)

for key, val in w.items():
    with open(f"./test_dataset_1/word_1/{key}.txt", "w", encoding="utf8") as f:
        f.writelines(val)

# %%
import os

regions = [r.removesuffix(".jpg") for r in os.listdir("./test_dataset_1/regions")]

lines = None
with open("./test_dataset_1/a.txt", "r", encoding="utf8") as rf:
    lines = rf.readlines()

words = None
with open("./test_dataset_1/b.txt", "r", encoding="utf8") as rf:
    words = rf.readlines()



res = [(r, sum([1 for i in lines if i.startswith(r)]), sum([1 for i in words if i.startswith(r)])) for r in regions]

# %%
res = list(sorted(res, key=lambda x: (x[1], x[2]), reverse=True))

# %%
# Example: assuming `dataset` is a list of tuples where each tuple is (image_path, num_lines, num_words)
total_lines = len(lines)
total_words = len(words)

train_target_lines = int(total_lines * 0.7)
val_target_lines = int(total_lines * 0.2)
test_target_lines = int(total_lines * 0.1) + 1 

train_target_words = int(total_words * 0.7)
val_target_words = int(total_words * 0.2)
test_target_words = int(total_words * 0.1) + 1

print(
    train_target_lines,
    val_target_lines,
    test_target_lines
)

print(
    train_target_words,
    val_target_words,
    test_target_words
)
# Out:
# 1163 332 167
# 4010 1145 573

# %%
train_set, val_set, test_set = [], [], []
train_lines, val_lines, test_lines = 0, 0, 0
train_words, val_words, test_words = 0, 0, 0

for image_path, num_lines, num_words in res:
    if train_lines + num_lines <= train_target_lines and train_words + num_words <= train_target_words:
        train_set.append(image_path)
        train_lines += num_lines
        train_words += num_words
    elif val_lines + num_lines <= val_target_lines and val_words + num_words <= val_target_words:
        val_set.append(image_path)
        val_lines += num_lines
        val_words += num_words
    else:
        test_set.append(image_path)
        test_lines += num_lines
        test_words += num_words

# %%
print(f"Train set: {len(train_set)} images, {train_lines} lines, {train_words} words")
print(f"Validation set: {len(val_set)} images, {val_lines} lines, {val_words} words")
print(f"Test set: {len(test_set)} images, {test_lines} lines, {test_words} words")
# Out:
# Train set: 116 images, 868 lines, 4010 words
# Validation set: 65 images, 332 lines, 1086 words
# Test set: 122 images, 262 lines, 433 words

# %%
t = 868+332+262
print(868/t, 332/t, 262/t)
t=4010+1086+433
print(4010/t, 1086/t, 433/t)
# Out:
# 0.5937072503419972 0.2270861833105335 0.17920656634746923
# 0.7252667751853862 0.19641888225718937 0.07831434255742449

# %%
with open("./test_dataset_1/regions_sets_1/train_set.txt", "w") as wf:
    wf.writelines([f"{t}\n" for t in train_set])

with open("./test_dataset_1/regions_sets_1/val_set.txt", "w") as wf:
    wf.writelines([f"{t}\n" for t in val_set])

with open("./test_dataset_1/regions_sets_1/test_set.txt", "w") as wf:
    wf.writelines([f"{t}\n" for t in test_set])

# %%
lines = None
with open("./test_dataset_1/a.txt", "r", encoding="utf8") as rf:
    lines = rf.readlines()

words = None
with open("./test_dataset_1/b.txt", "r", encoding="utf8") as rf:
    words = rf.readlines()

test = None
with open("./test_dataset_1/regions_sets_1/test_set.txt", "r") as rf:
    test = rf.readlines()


val = None
with open("./test_dataset_1/regions_sets_1/val_set.txt", "r") as rf:
    val = rf.readlines()


train = None
with open("./test_dataset_1/regions_sets_1/train_set.txt", "r") as rf:
    train = rf.readlines()


w = {
    "train": [i for i in words for j in train if i.startswith(j.removesuffix("\n"))],
    "test": [i for i in words for j in test if i.startswith(j.removesuffix("\n"))],
    "val": [i for i in words for j in val if i.startswith(j.removesuffix("\n"))],
}

l = {
    "train": [i for i in lines for j in train if i.startswith(j.removesuffix("\n"))],
    "test": [i for i in lines for j in test if i.startswith(j.removesuffix("\n"))],
    "val": [i for i in lines for j in val if i.startswith(j.removesuffix("\n"))],
}


for key, val in l.items():
    with open(f"./test_dataset_1/line_2/{key}.txt", "w", encoding="utf8") as f:
        f.writelines(val)

for key, val in w.items():
    with open(f"./test_dataset_1/word_2/{key}.txt", "w", encoding="utf8") as f:
        f.writelines(val)

# %%
import os

regions = [r.removesuffix(".jpg") for r in os.listdir("./test_dataset_1/regions")]

lines = None
with open("./a/a.txt", "r", encoding="utf8") as rf:
    lines = rf.readlines()

words = None
with open("./a/b.txt", "r", encoding="utf8") as rf:
    words = rf.readlines()

# %%
from sklearn.model_selection import train_test_split

rest_of_data, test_data = train_test_split(regions, test_size=0.1)

print(len(rest_of_data), len(test_data))
# Out:
# 272 31

# %%
print("words", len(words))
print("lines", len(lines))
words1 = [j for i in rest_of_data for j in words if j.startswith(i)]
lines1 = [j for i in rest_of_data for j in lines if j.startswith(i)]
print("words", len(words1))
print("lines", len(lines1))
words2 = [j for i in test_data for j in words if j.startswith(i)]
lines2 = [j for i in test_data for j in lines if j.startswith(i)]
print("words", len(words2))
print("lines", len(lines2))
# Out:
# words 5621
# lines 1476
# words 5047
# lines 1309
# words 574
# lines 167

# %%
with open("./tmp.txt", "w", encoding="utf8") as wf:
    wf.writelines(lines1)
split_train_set("./tmp.txt", "./htr_data/v15/ml_line_data")




with open("./tmp.txt", "w", encoding="utf8") as wf:
    wf.writelines(words1)
split_train_set("./tmp.txt", "./htr_data/v16/ml_word_data")


os.remove("./tmp.txt")

# %%
with open("./htr_data/v17/lines.txt", "w", encoding="utf8") as wf:
    wf.writelines(lines2)


with open("./htr_data/v17/words.txt", "w", encoding="utf8") as wf:
    wf.writelines(words2)

# %%
import os

nums = list(os.listdir("./test_dataset_1/nums_ttv"))

ttv_nums = {
}
for n in nums:
    with open(f"./test_dataset_1/nums_ttv/{n}", "r", encoding="utf8") as rf:
        ttv_nums[n.removesuffix(".txt")] = rf.readlines()

for key, val in ttv_nums.items():
    with open(f"./htr_data/v15/ml_line_data/{key}.txt", "a", encoding="utf8") as af:
        af.writelines(val)
    with open(f"./htr_data/v16/ml_word_data/{key}.txt", "a", encoding="utf8") as af:
        af.writelines(val)
