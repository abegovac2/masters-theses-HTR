# %% [markdown]
# ## File conversion from .gif to .jpg

# %% [markdown]
# ### Setup folders

# %%
import os

def setup_folders(input: str, output):
    input_folders = [
        f"./{input}/FormatA",
        f"./{input}/FormatB"
    ]
    output_folders = [
        f"./{output}/FormatA",
        f"./{output}/FormatB",
    ]

    if not os.path.isdir(f"./{output}"):
        os.mkdir(f"./{output}")
    if not os.path.isdir(f"./{output}/FormatA"):
        os.mkdir(f"./{output}/FormatA")
    if not os.path.isdir(f"./{output}/FormatB"):
        os.mkdir(f"./{output}/FormatB")

    return input_folders, output_folders


input_folders, output_folders = setup_folders("MINSKI_ZAPISNICI_SORTIRANO_ZAJEDNO","jpg_minski_zapisnici")

# %% [markdown]
# ### Convert images

# %%
from utils import convert_gif_to_jpg
from time import time

num_threads = 5

folders = list(zip(input_folders, output_folders))
for input_folder, output_folder in folders:
    print(f"Folder {input_folder}")
    print("Start convert...")
    s = time()
    convert_gif_to_jpg(input_folder, output_folder, num_threads)
    e = time()
    print(f"End convert, time took {e-s}")
# Out:
# Folder ./MINSKI_ZAPISNICI_SORTIRANO_ZAJEDNO/FormatA
# Start convert...
# Converted 30519.gif to JPG
# Converted 30520.gif to JPG
# Converted 30706.gif to JPG
# Converted 30535.gif to JPG
# Converted 30543.gif to JPG
# Converted 30960.gif to JPG
# Converted 30926.gif to JPG
# Converted 30967.gif to JPG
# Converted 30925.gif to JPG
# Converted 30922.gif to JPG
# Converted 30969.gif to JPG
# Converted 30972.gif to JPG
# Converted 30977a.gif to JPG
# Converted 31131.gif to JPG
# Converted 31094.gif to JPG
# Converted 31142.gif to JPG
# Converted 31139.gif to JPG
# Converted 31150.gif to JPG
# Converted 31136.gif to JPG
# Converted 31138.gif to JPG
# Converted 33021a.gif to JPG
# Converted 32862.gif to JPG
# Converted 33021b.gif to JPG
# Converted 32860.gif to JPG
# Converted 31190.gif to JPG
# Converted 40688.gif to JPG
# Converted 50677.gif to JPG
# Converted 50678.gif to JPG
# Converted 50676.gif to JPG
# Converted 33238.gif to JPG
# Converted 50690.gif to JPG
# Converted 50685.gif to JPG
# Converted 50684.gif to JPG
# Converted 50682.gif to JPG
# Converted 50689.gif to JPG
# Converted 50691.gif to JPG
# Converted 51356.gif to JPG
# Converted 51355.gif to JPG
# Converted 51358.gif to JPG
# Converted 51357.gif to JPG
# Converted 51362.gif to JPG
# Converted 51359.gif to JPG
# Converted 51363.gif to JPG
# Converted 51361.gif to JPG
# Converted 51364.gif to JPG
# Converted 51385.gif to JPG
# Converted 51374.gif to JPG
# Converted 51365.gif to JPG
# Converted gp 835.gif to JPG
# Converted gp 750.gif to JPG
# Converted gp 838.gif to JPG
# Converted gp 839.gif to JPG
# Converted gp 892.gif to JPG
# Converted gp 982.gif to JPG
# Converted gp1002b.gif to JPG
# Converted gp1028.gif to JPG
# Converted gp1027.gif to JPG
# Converted gp1029.gif to JPG
# Converted gp1026.gif to JPG
# Converted gp1025.gif to JPG
# Converted gp1033.gif to JPG
# Converted gp1032.gif to JPG
# Converted gp1031.gif to JPG
# Converted gp1034.gif to JPGConverted gp1030.gif to JPG
#
# Converted gp1219.gif to JPG
# Converted gp1328.gif to JPG
# Converted gp1330.gif to JPG
# Converted gp1331.gif to JPG
# Converted gp1329.gif to JPG
# Converted gp1334.gif to JPG
# Converted gp1336.gif to JPG
# Converted gp1333.gif to JPG
# Converted gp1335.gif to JPG
# Converted gp1332.gif to JPG
# Converted gp1338.gif to JPG
# Converted gp1341b.gif to JPG
# Converted gp1339.gif to JPG
# Converted gp1342.gif to JPG
# Converted gp1337.gif to JPG
# Converted gp1650.gif to JPG
# Converted gp1649.gif to JPG
# Converted gp1648.gif to JPG
# Converted gp1642.gif to JPG
# Converted gp1651.gif to JPG
# Converted gp1657.gif to JPG
# Converted gp1652.gif to JPG
# Converted gp1654.gif to JPG
# Converted gp1658.gif to JPG
# Converted gp1656.gif to JPG
# Converted gp1661.gif to JPG
# Converted gp1658b.gif to JPG
# Converted gp1660.gif to JPG
# Converted gp1659.gif to JPG
# Converted gp1667.gif to JPG
# Converted gp1761.gif to JPG
# Converted gp1673.gif to JPG
# Converted gp1671.gif to JPG
# Converted gp1669.gif to JPG
# Converted gp1674.gif to JPG
# Converted gp2176.gif to JPG
# Converted gp2175.gif to JPG
# Converted gp2177.gif to JPG
# Converted gp2260.gif to JPG
# Converted gp2259.gif to JPG
# Converted hcr_31144b.gif to JPG
# Converted hcr_31133b.gif to JPG
# Converted hcr_31144a.gif to JPG
# Converted hcr_31133a.gif to JPG
# Converted gp2261.gif to JPG
# Converted un1041b.gif to JPG
# Converted un1080.gif to JPG
# Converted un1027.gif to JPG
# Converted un1041a.gif to JPG
# Converted un1090.gif to JPG
# Converted un1118.gif to JPG
# Converted un1177.gif to JPG
# Converted un1091.gif to JPG
# Converted un1178.gif to JPG
# Converted un1182.gif to JPG
# Converted un1188.gif to JPG
# Converted un1239.gif to JPG
# Converted un1194.gif to JPG
# Converted un1184.gif to JPG
# Converted un1183.gif to JPG
# Converted un1246.gif to JPG
# Converted un1242.gif to JPG
# Converted un1269a.gif to JPG
# Converted un1247.gif to JPG
# Converted un1243.gif to JPG
# Converted un1269b.gif to JPG
# Converted un1271.gif to JPG
# Converted un1272b.gif to JPG
# Converted un1272a.gif to JPG
# Converted un1270.gif to JPG
# Converted un951.gif to JPG
# Converted un1274.gif to JPG
# Converted zmp112.gif to JPG
# Converted zmp113.gif to JPG
# Converted zmp111.gif to JPG
# Converted zmp121.gif to JPG
# Converted zmp114.gif to JPG
# Converted zmp122.gif to JPG
# Converted zmp119.gif to JPG
# Converted zmp118.gif to JPG
# Converted zmp126.gif to JPG
# Converted zmp125.gif to JPG
# Converted zmp124.gif to JPG
# Converted zmp123.gif to JPG
# Converted zmp127.gif to JPG
# Converted zmp128.gif to JPG
# Converted zmp129.gif to JPG
# Converted zmp130.gif to JPG
# Converted zmp131.gif to JPG
# Converted zmp132.gif to JPG
# Converted zmp135.gif to JPG
# Converted zmp136.gif to JPG
# Converted zmp134.gif to JPG
# Converted zmp133.gif to JPG
# Converted zmp137.gif to JPG
# Converted zmp142.gif to JPG
# Converted zmp140.gif to JPG
# Converted zmp138.gif to JPG
# Converted zmp139.gif to JPG
# Converted zmp141.gif to JPG
# Converted zmp146.gif to JPG
# Converted zmp144.gif to JPG
# Converted zmp149.gif to JPG
# Converted zmp150.gif to JPG
# Converted zmp147.gif to JPG
# Converted zmp151.gif to JPG
# Converted zmp154.gif to JPG
# Converted zmp155.gif to JPG
# Converted zmp153.gif to JPG
# Converted zmp152.gif to JPG
# Converted zmp158.gif to JPG
# Converted zmp157.gif to JPG
# Converted zmp160.gif to JPG
# Converted zmp156.gif to JPG
# Converted zmp159.gif to JPG
# Converted zmp163.gif to JPG
# Converted zmp164.gif to JPG
# Converted zmp162.gif to JPG
# Converted zmp161.gif to JPG
# Converted zmp165.gif to JPG
# Converted zmp168.gif to JPG
# Converted zmp166.gif to JPG
# Converted zmp167.gif to JPG
# Converted zmp169.gif to JPG
# Converted zmp170.gif to JPG
# Converted zmp171.gif to JPG
# Converted zmp172.gif to JPG
# End convert, time took 3.7930614948272705
# Folder ./MINSKI_ZAPISNICI_SORTIRANO_ZAJEDNO/FormatB
# Start convert...
# Converted 31146b.gif to JPG
# Converted 31146a.gif to JPG
# Converted 31164.gif to JPG
# Converted 31153.gif to JPG
# Converted 31163a.gif to JPG
# Converted 31165.gif to JPG
# Converted 31169b.gif to JPG
# Converted 31167.gif to JPG
# Converted 31171.gif to JPG
# Converted 31169a.gif to JPG
# Converted hcr_31157a.gif to JPG
# Converted hcr_31157b.gif to JPG
# End convert, time took 0.29419994354248047

# %% [markdown]
# ## Cleaning images

# %%
input_folders, output_folders = setup_folders("jpg_minski_zapisnici", "jpg_minski_zapisnici_clean")

# %%
from utils.clean_image_pipeline import apply_image_cleaning_pipeline

input_path = "./jpg_minski_zapisnici/FormatA/30543.jpg"
output_path = "./jpg_minski_zapisnici_clean/FormatA/30543.jpg"

apply_image_cleaning_pipeline(input_path, output_path)

# %%
from time import time
from utils.clean_image_pipeline import apply_image_cleaning_pipeline
import threading

num_threads = 5
folders = list(zip(input_folders, output_folders))
for input_folder, output_folder in folders:
    print(f"Folder {input_folder}")
    print("Start clean...")
    s = time()
    images = os.listdir(input_folder)
    threads = []

    for in_image in images:
        image1, image2 = f"{input_folder}/{in_image}", f"{output_folder}/{in_image}"
        print("In: ", image1)
        print("Out: ", image2)
        thread = threading.Thread(target=apply_image_cleaning_pipeline, args=(image1, image2))
        thread.start()
        threads.append(thread)
        if len(threads) >= num_threads:
            for thread in threads:
                thread.join()
            threads = []
        #apply_image_cleaning_pipeline(image1, image2)
    e = time()
    print(f"End clean, time took {e-s}")
# Out:
# Folder ./jpg_minski_zapisnici/FormatA
# Start clean...
# In:  ./jpg_minski_zapisnici/FormatA/30519.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30519.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30520.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30520.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30535.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30535.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30543.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30543.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30706.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30706.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30922.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30922.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30925.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30925.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30926.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30926.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30960.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30960.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30967.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30967.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30969.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30969.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30972.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30972.jpg
# In:  ./jpg_minski_zapisnici/FormatA/30977a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/30977a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31094.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31094.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31131.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31131.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31136.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31136.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31138.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31138.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31139.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31139.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31142.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31142.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31150.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31150.jpg
# In:  ./jpg_minski_zapisnici/FormatA/31190.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/31190.jpg
# In:  ./jpg_minski_zapisnici/FormatA/32860.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/32860.jpg
# In:  ./jpg_minski_zapisnici/FormatA/32862.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/32862.jpg
# In:  ./jpg_minski_zapisnici/FormatA/33021a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/33021a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/33021b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/33021b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/33238.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/33238.jpg
# In:  ./jpg_minski_zapisnici/FormatA/40688.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/40688.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50676.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50676.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50677.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50677.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50678.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50678.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50682.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50682.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50684.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50684.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50685.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50685.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50689.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50689.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50690.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50690.jpg
# In:  ./jpg_minski_zapisnici/FormatA/50691.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/50691.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51355.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51355.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51356.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51356.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51357.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51357.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51358.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51358.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51359.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51359.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51361.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51361.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51362.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51362.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51363.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51363.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51364.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51364.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51365.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51365.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51374.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51374.jpg
# In:  ./jpg_minski_zapisnici/FormatA/51385.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/51385.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 750.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 750.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 835.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 835.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 838.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 838.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 839.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 839.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 892.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 892.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp 982.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp 982.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1002b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1002b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1025.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1025.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1026.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1026.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1027.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1027.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1028.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1028.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1029.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1029.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1030.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1030.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1031.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1031.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1032.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1032.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1033.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1033.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1034.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1034.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1219.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1219.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1328.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1328.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1329.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1329.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1330.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1330.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1331.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1331.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1332.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1332.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1333.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1333.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1334.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1334.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1335.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1335.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1336.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1336.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1337.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1337.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1338.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1338.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1339.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1339.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1341b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1341b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1342.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1342.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1642.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1642.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1648.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1648.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1649.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1649.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1650.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1650.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1651.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1651.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1652.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1652.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1654.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1654.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1656.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1656.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1657.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1657.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1658.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1658.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1658b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1658b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1659.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1659.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1660.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1660.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1661.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1661.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1667.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1667.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1669.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1669.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1671.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1671.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1673.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1673.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1674.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1674.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp1761.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp1761.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2175.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2175.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2176.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2176.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2177.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2177.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2259.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2259.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2260.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2260.jpg
# In:  ./jpg_minski_zapisnici/FormatA/gp2261.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/gp2261.jpg
# In:  ./jpg_minski_zapisnici/FormatA/hcr_31133a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/hcr_31133a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/hcr_31133b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/hcr_31133b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/hcr_31144a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/hcr_31144a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/hcr_31144b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/hcr_31144b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1027.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1027.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1041a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1041a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1041b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1041b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1080.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1080.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1090.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1090.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1091.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1091.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1118.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1118.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1177.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1177.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1178.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1178.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1182.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1182.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1183.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1183.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1184.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1184.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1188.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1188.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1194.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1194.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1239.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1239.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1242.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1242.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1243.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1243.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1246.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1246.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1247.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1247.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1269a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1269a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1269b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1269b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1270.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1270.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1271.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1271.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1272a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1272a.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1272b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1272b.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un1274.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un1274.jpg
# In:  ./jpg_minski_zapisnici/FormatA/un951.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/un951.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp111.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp111.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp112.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp112.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp113.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp113.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp114.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp114.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp118.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp118.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp119.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp119.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp121.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp121.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp122.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp122.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp123.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp123.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp124.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp124.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp125.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp125.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp126.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp126.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp127.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp127.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp128.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp128.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp129.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp129.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp130.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp130.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp131.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp131.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp132.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp132.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp133.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp133.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp134.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp134.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp135.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp135.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp136.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp136.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp137.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp137.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp138.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp138.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp139.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp139.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp140.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp140.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp141.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp141.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp142.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp142.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp144.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp144.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp146.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp146.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp147.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp147.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp149.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp149.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp150.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp150.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp151.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp151.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp152.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp152.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp153.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp153.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp154.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp154.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp155.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp155.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp156.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp156.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp157.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp157.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp158.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp158.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp159.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp159.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp160.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp160.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp161.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp161.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp162.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp162.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp163.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp163.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp164.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp164.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp165.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp165.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp166.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp166.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp167.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp167.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp168.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp168.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp169.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp169.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp170.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp170.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp171.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp171.jpg
# In:  ./jpg_minski_zapisnici/FormatA/zmp172.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatA/zmp172.jpg
# End clean, time took 131.79463052749634
# Folder ./jpg_minski_zapisnici/FormatB
# Start clean...
# In:  ./jpg_minski_zapisnici/FormatB/31146a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31146a.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31146b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31146b.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31153.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31153.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31163a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31163a.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31164.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31164.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31165.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31165.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31167.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31167.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31169a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31169a.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31169b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31169b.jpg
# In:  ./jpg_minski_zapisnici/FormatB/31171.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/31171.jpg
# In:  ./jpg_minski_zapisnici/FormatB/hcr_31157a.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/hcr_31157a.jpg
# In:  ./jpg_minski_zapisnici/FormatB/hcr_31157b.jpg
# Out:  ./jpg_minski_zapisnici_clean/FormatB/hcr_31157b.jpg
# End clean, time took 8.650370597839355

# %% [markdown]
# ## Region detection

# %% [markdown]
# ### Manual region detection

# %%
from utils.extract_regions import extract_interesting_regions
import cv2
image_path = "./jpg_minski_zapisnici_clean/FormatA/30543.jpg"
out_path = "./tmp/region_detection12_"

image = cv2.imread(image_path)
regions = extract_interesting_regions(image)

for i, region in enumerate(regions):
    a = f"{out_path}{i}.jpg"
    print(a)
    if len(region) > 0:
        print("write")
        cv2.imwrite(a, region)
# Out:
# ./tmp/region_detection12_0.jpg
# write
# ./tmp/region_detection12_1.jpg
# write
# ./tmp/region_detection12_2.jpg
# write
# ./tmp/region_detection12_3.jpg
# write
# ./tmp/region_detection12_4.jpg
# write
# ./tmp/region_detection12_5.jpg
# write
# ./tmp/region_detection12_6.jpg
# write
# ./tmp/region_detection12_7.jpg
# write

# %%
input_folders, output_folders = setup_folders("jpg_minski_zapisnici_clean","jpg_minski_zapisnici_clean_manual_regions")

# %%
from time import time
from utils.extract_regions import extract_interesting_regions
import threading

def extract_interesting_regions_threading(src: str, dest: str):
    empty, dest, ext = dest.split('.')
    image = cv2.imread(src)
    regions = extract_interesting_regions(image)

    for i, region in enumerate(regions):
        a = f".{dest}_{i}.{ext}"
        if len(region) > 0:
            cv2.imwrite(a, region)

num_threads = 5
folders = list(zip(input_folders, output_folders))
for input_folder, output_folder in folders:
    print(f"Folder {input_folder}")
    print("Start clean...")
    s = time()
    images = os.listdir(input_folder)
    threads = []

    for in_image in images:
        image1, image2 = f"{input_folder}/{in_image}", f"{output_folder}/{in_image}"
        print("In: ", image1)
        print("Out: ", image2)
        #extract_interesting_regions_threading(image1, image2)
        #"""
        thread = threading.Thread(target=extract_interesting_regions_threading, args=(image1, image2))
        thread.start()
        threads.append(thread)
        if len(threads) >= num_threads:
            for thread in threads:
                thread.join()
            threads = []
        #"""
    e = time()
    print(f"End clean, time took {e-s}")

# %% [markdown]
# Results not good, because of the state of the images the line detection, which is predominantly used for this action, cannot work correctly most of the time.
# Best way is to use ML assistance for this work.

# %% [markdown]
# ### ML region detection

# %%
# !pip install ultralytics==8.0.227

# %%
from ultralytics import YOLO

model_path = "./models/region_detection_model.pt"
img_path = "./jpg_minski_zapisnici_clean/FormatA/30519.jpg"
model = YOLO(model_path)
import cv2
image = cv2.imread(img_path)

results = model.predict(source=image, imgsz=640,conf=0.25,iou=0.45)
results = results[0]  
for i in range(len(results.boxes)):
        box = results.boxes[i]
        cls = results.cls
        tensor = box.xyxy[0]
        x1 = int(tensor[0].item())
        y1 = int(tensor[1].item())
        x2 = int(tensor[2].item())
        y2 = int(tensor[3].item())
        cv2.rectangle(image,(x1,y1),(x2,y2),(255,0,0),3) 

a= "./tmp/30519-regions-drawings.jpg"
cv2.imwrite(a,image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 11
#       7 image = cv2.imread(img_path)
#       8 #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       9 #image = image_resize(image, height=640)
# ---> 11 results = model.predict(source=image, imgsz=640,conf=0.25,iou=0.45)
#      12 results = results[0]
#      13 for i in range(len(results.boxes)):
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\ultralytics\engine\model.py:232, in Model.predict(self, source, stream, predictor, **kwargs)
#     230 if not self.predictor:
#     231     self.predictor = (predictor or self._smart_load('predictor'))(overrides=args, _callbacks=self.callbacks)
# --> 232     self.predictor.setup_model(model=self.model, verbose=is_cli)
#     233 else:  # only update args if predictor is already setup
#     234     self.predictor.args = get_cfg(self.predictor.args, args)
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\ultralytics\engine\predictor.py:317, in BasePredictor.setup_model(self, model, verbose)
#     315 def setup_model(self, model, verbose=True):
#     316     """Initialize YOLO model with given parameters and set it to evaluation mode."""
# --> 317     self.model = AutoBackend(model or self.args.model,
#     318                              device=select_device(self.args.device, verbose=verbose),
#     319                              dnn=self.args.dnn,
#     320                              data=self.args.data,
#     321                              fp16=self.args.half,
#     322                              fuse=True,
#     323                              verbose=verbose)
#     325     self.device = self.model.device  # update device
#     326     self.args.half = self.model.fp16  # update half
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\ultralytics\nn\autobackend.py:104, in AutoBackend.__init__(self, weights, device, dnn, data, fp16, fuse, verbose)
#     101 w = str(weights[0] if isinstance(weights, list) else weights)
#     102 nn_module = isinstance(weights, torch.nn.Module)
#     103 pt, jit, onnx, xml, engine, coreml, saved_model, pb, tflite, edgetpu, tfjs, paddle, ncnn, triton = \
# --> 104     self._model_type(w)
#     105 fp16 &= pt or jit or onnx or xml or engine or nn_module or triton  # FP16
#     106 nhwc = coreml or saved_model or pb or tflite or edgetpu  # BHWC formats (vs torch BCWH)
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\ultralytics\nn\autobackend.py:501, in AutoBackend._model_type(p)
#     498 # Return model type from model path, i.e. path='path/to/model.onnx' -> type=onnx
#     499 # types = [pt, jit, onnx, xml, engine, coreml, saved_model, pb, tflite, edgetpu, tfjs, paddle]
#     500 from ultralytics.engine.exporter import export_formats
# --> 501 sf = list(export_formats().Suffix)  # export suffixes
#     502 if not is_url(p, check=False) and not isinstance(p, str):
#     503     check_suffix(p, sf)  # checks
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\ultralytics\engine\exporter.py:81, in export_formats()
#      79 def export_formats():
#      80     """YOLOv8 export formats."""
# ---> 81     import pandas
#      82     x = [
#      83         ['PyTorch', '-', '.pt', True, True],
#      84         ['TorchScript', 'torchscript', '.torchscript', True, True],
#    (...)
#      94         ['PaddlePaddle', 'paddle', '_paddle_model', True, True],
#      95         ['ncnn', 'ncnn', '_ncnn_model', True, True], ]
#      96     return pandas.DataFrame(x, columns=['Format', 'Argument', 'Suffix', 'CPU', 'GPU'])
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\pandas\__init__.py:151
#     132 from pandas.core.computation.api import eval
#     134 from pandas.core.reshape.api import (
#     135     concat,
#     136     lreshape,
#    (...)
#     148     qcut,
#     149 )
# --> 151 from pandas import api, arrays, errors, io, plotting, tseries
#     152 from pandas import testing
#     153 from pandas.util._print_versions import show_versions
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)
#      15     "typing",
#      16 ]
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\pandas\api\typing\__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)
#      26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)
#      54     "Window",
#      55 ]
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\pandas\io\json\__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)
#      14     "build_table_schema",
#      15 ]
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\pandas\io\json\_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\pandas\io\parsers\__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File c:\Users\abego\OneDrive\Desktop\Master\code\venv\lib\site-packages\pandas\io\parsers\readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %%
from ultralytics import YOLO
model_path = "./models/region_detection_model.pt"
extract_interesting_regions_ml_model = YOLO(model_path)


def extract_interesting_regions_ml(image):
    results = extract_interesting_regions_ml_model.predict(source=image,imgsz=640,conf=0.25,iou=0.45)
    results = results[0]
    boxes = results.boxes
    classes = boxes.cls
    zipped = list(zip(classes, boxes))
    rectangles = []
    classes = []
    for cls, box in zipped:
        tensor = box.xyxy[0]
        x1 = int(tensor[0].item())
        y1 = int(tensor[1].item())
        x2 = int(tensor[2].item())
        y2 = int(tensor[3].item())
        rectangles.append([[x1,y1],[x2, y2]])
        classes.append(int(cls))
    return rectangles, classes

# %%
input_folders, output_folders = setup_folders("jpg_minski_zapisnici_clean","jpg_minski_zapisnici_clean_ml_regions")

# %%
from time import time
import threading
import cv2
from utils.extract_regions import extract_rectangle

def extract_interesting_regions_threading(src: str, dest: str):
    empty, dest, ext = dest.split('.')
    image = cv2.imread(src)
    regions, classes = extract_interesting_regions_ml(image)
    regions = [extract_rectangle(image, region[0], region[1]) for region in regions]
    regions = list(zip(classes, regions))
    for i, region in regions:
        a = f".{dest}_{i}.{ext}"
        if len(region) > 0:
            written = cv2.imwrite(a, region)
            print("Is written", written)

num_threads = 5
folders = list(zip(input_folders, output_folders))
for input_folder, output_folder in folders:
    print(f"Folder {input_folder}")
    print("Start clean...")
    s = time()
    images = os.listdir(input_folder)
    threads = []

    for in_image in images:
        image1, image2 = f"{input_folder}/{in_image}", f"{output_folder}/{in_image}"
        print("In: ", image1)
        print("Out: ", image2)
        #extract_interesting_regions_threading(image1, image2)
        #"""
        thread = threading.Thread(target=extract_interesting_regions_threading, args=(image1, image2))
        thread.start()
        threads.append(thread)
        if len(threads) >= num_threads:
            for thread in threads:
                thread.join()
            threads = []
        #"""
    e = time()
    print(f"End clean, time took {e-s}")
# Out:
# Folder ./jpg_minski_zapisnici_clean/FormatA
# Start clean...
# In:  ./jpg_minski_zapisnici_clean/FormatA/30519.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30519.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30520.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30520.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30535.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30535.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30543.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30543.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30706.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30706.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 90.4ms
# Speed: 20.9ms preprocess, 90.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 97.2ms
# Speed: 8.3ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 96.8ms
# Speed: 5.1ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 92.9ms
# Speed: 8.1ms preprocess, 92.9ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 92.3ms
# Speed: 9.1ms preprocess, 92.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/30922.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30922.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30925.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30925.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30926.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30926.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30960.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30960.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30967.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30967.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 64.8ms
# Speed: 19.3ms preprocess, 64.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 106.3ms
# Speed: 0.0ms preprocess, 106.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 104.3ms
# Is written True
# Speed: 3.1ms preprocess, 104.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is writtenIs written True
#  True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 99.1ms
# Speed: 9.6ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 101.1ms
# Speed: 7.5ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is writtenIs written True
#  True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/30969.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30969.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30972.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30972.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/30977a.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/30977a.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/31094.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/31094.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/31131.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/31131.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 71.8ms
# Speed: 10.1ms preprocess, 71.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 101.5ms
# Speed: 8.0ms preprocess, 101.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 114.3ms
# Speed: 6.0ms preprocess, 114.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 2 records, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 103.4ms
# Speed: 2.0ms preprocess, 103.4ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 106.3ms
# Speed: 6.6ms preprocess, 106.3ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/31136.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/31136.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/31138.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/31138.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/31139.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/31139.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/31142.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/31142.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/31150.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/31150.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 69.9ms
# Speed: 14.5ms preprocess, 69.9ms inference, 11.5ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 99.9ms
# Speed: 13.1ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 102.0ms
# Speed: 9.1ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 103.5ms
# Speed: 7.0ms preprocess, 103.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 117.1ms
# Speed: 12.0ms preprocess, 117.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is writtenIs written True
#  True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/31190.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/31190.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/32860.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/32860.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/32862.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/32862.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/33021a.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/33021a.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/33021b.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/33021b.jpg
#
#
#
#
#
# 0: 640x480 1 map, 63.6ms
# Speed: 9.1ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 2 detailed informations, 1 unit record, 1 demainer information, 70.4ms
# Speed: 13.0ms preprocess, 70.4ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 90.8ms
# Speed: 16.1ms preprocess, 90.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 109.3ms
# Speed: 10.3ms preprocess, 109.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 96.8ms
# Speed: 6.2ms preprocess, 96.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/33238.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/33238.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/40688.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/40688.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/50676.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/50676.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/50677.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/50677.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/50678.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/50678.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 89.3ms
# Speed: 6.6ms preprocess, 89.3ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 90.0ms
# Speed: 8.1ms preprocess, 90.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 124.5ms
# Speed: 7.5ms preprocess, 124.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 2 records, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 84.7ms
# Speed: 10.9ms preprocess, 84.7ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 83.8ms
# Speed: 4.0ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/50682.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/50682.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/50684.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/50684.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/50685.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/50685.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/50689.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/50689.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/50690.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/50690.jpg
#
#
#
#
#
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 74.1ms
# Speed: 18.4ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 2 records, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 95.3ms
# Speed: 2.0ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 96.5ms
# Speed: 5.2ms preprocess, 96.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 84.0ms
# Speed: 7.8ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 95.0ms
# Speed: 0.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/50691.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/50691.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51355.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51355.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51356.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51356.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51357.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51357.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51358.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51358.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 82.0ms
# Speed: 9.9ms preprocess, 82.0ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 demainer information, 96.8ms
# Speed: 0.0ms preprocess, 96.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 2 structures, 1 detailed information, 1 demainer information, 1 demining information, 90.5ms
# Speed: 0.0ms preprocess, 90.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 2 records, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 demainer information, 1 demining information, 101.8ms
# Speed: 10.1ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 demainer information, 1 demining information, 92.0ms
# Speed: 10.1ms preprocess, 92.0ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/51359.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51359.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51361.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51361.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51362.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51362.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51363.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51363.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51364.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51364.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 demainer information, 92.2ms
# Speed: 10.1ms preprocess, 92.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 2 structures, 1 detailed information, 1 unit record, 1 demainer information, 80.7ms
# Speed: 4.0ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 demainer information, 91.2ms
# Speed: 0.0ms preprocess, 91.2ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 1 map, 1 legend, 2 structures, 1 detailed information, 1 demainer information, 1 demining information, 78.2ms
# Speed: 4.0ms preprocess, 78.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 2 overheads, 1 record, 2 maps, 1 legend, 2 structures, 1 detailed information, 1 demainer information, 1 demining information, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/51365.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51365.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51374.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51374.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/51385.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/51385.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp 750.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp 750.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp 835.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp 835.jpg
#
#
#
#
#
# 0: 640x480 1 overhead, 2 records, 2 maps, 1 legend, 2 structures, 1 detailed information, 1 demainer information, 1 demining information, 101.5ms
# Speed: 10.2ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 2 structures, 1 detailed information, 1 demainer information, 1 demining information, 89.3ms
# Speed: 5.3ms preprocess, 89.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 demainer information, 86.3ms
# Speed: 9.8ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 104.1ms
# Speed: 6.1ms preprocess, 104.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 96.8ms
# Speed: 13.0ms preprocess, 96.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp 838.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp 838.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp 839.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp 839.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp 892.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp 892.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp 982.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp 982.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1002b.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1002b.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 demainer information, 1 demining information, 107.8ms
# Speed: 9.8ms preprocess, 107.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 103.3ms
# Speed: 8.1ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 115.2ms
# Speed: 6.8ms preprocess, 115.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 112.5ms
# Speed: 11.4ms preprocess, 112.5ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 116.7ms
# Speed: 11.7ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1025.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1025.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1026.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1026.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1027.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1027.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1028.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1028.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1029.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1029.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 76.8ms
# Speed: 21.1ms preprocess, 76.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 112.4ms
# Speed: 0.0ms preprocess, 112.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is writtenIs written True
#  True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 101.3ms
# Speed: 10.3ms preprocess, 101.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 2 structures, 1 detailed information, 1 demainer information, 113.0ms
# Speed: 3.6ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 119.6ms
# Speed: 7.0ms preprocess, 119.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1030.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1030.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1031.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1031.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1032.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1032.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1033.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1033.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1034.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1034.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 86.2ms
# Speed: 0.0ms preprocess, 86.2ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 102.2ms
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 2 structures, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 149.5ms
# Speed: 7.5ms preprocess, 149.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 97.7ms
# Speed: 10.1ms preprocess, 97.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 101.7ms
# Speed: 10.1ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1219.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1219.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1328.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1328.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1329.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1329.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1330.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1330.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1331.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1331.jpg
#
#
#
#
#
# 0: 640x512 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 74.6ms
# Speed: 29.1ms preprocess, 74.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 99.6ms
# Speed: 10.1ms preprocess, 99.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 108.0ms
# Speed: 7.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 3 structures, 1 detailed information, 1 demainer information, 99.4ms
# Speed: 6.0ms preprocess, 99.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 109.2ms
# Speed: 6.0ms preprocess, 109.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1332.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1332.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1333.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1333.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1334.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1334.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1335.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1335.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1336.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1336.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 77.5ms
# Speed: 9.6ms preprocess, 77.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 115.3ms
# Speed: 0.0ms preprocess, 115.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 115.6ms
# Speed: 7.2ms preprocess, 115.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 114.3ms
# Speed: 6.0ms preprocess, 114.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Is writtenIs written True
#  True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 118.0ms
# Speed: 3.2ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1337.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1337.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1338.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1338.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1339.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1339.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1341b.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1341b.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1342.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1342.jpg
#
#
#
#
#
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 63.5ms
# Speed: 24.8ms preprocess, 63.5ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 96.6ms
# Speed: 16.1ms preprocess, 96.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 118.6ms
# Speed: 8.1ms preprocess, 118.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 99.8ms
# Speed: 6.5ms preprocess, 99.8ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 126.5ms
# Speed: 1.7ms preprocess, 126.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1642.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1642.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1648.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1648.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1649.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1649.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1650.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1650.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1651.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1651.jpg
#
#
#
#
#
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 66.0ms
# Speed: 22.6ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 103.4ms
# Speed: 20.2ms preprocess, 103.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 112.6ms
# Speed: 7.1ms preprocess, 112.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 102.9ms
# Speed: 6.0ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 117.5ms
# Is written True
# Speed: 0.0ms preprocess, 117.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1652.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1652.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1654.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1654.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1656.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1656.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1657.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1657.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1658.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1658.jpg
#
#
#
#
#
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 80.3ms
# Speed: 20.5ms preprocess, 80.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 96.4ms
# Speed: 6.4ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 99.6ms
# Speed: 11.1ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 103.3ms
# Speed: 10.1ms preprocess, 103.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 110.7ms
# Speed: 8.1ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1658b.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1658b.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1659.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1659.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1660.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1660.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1661.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1661.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/gp1667.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/gp1667.jpg
#
#
#
#
#
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 95.3ms
# Speed: 10.9ms preprocess, 95.3ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 100.8ms
# Speed: 16.1ms preprocess, 100.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# ...
# Speed: 7.6ms preprocess, 120.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 109.3ms
# Speed: 2.0ms preprocess, 109.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 114.7ms
# Speed: 13.6ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp156.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp156.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp157.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp157.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp158.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp158.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp159.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp159.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp160.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp160.jpg
#
#
#
#
#
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 87.2ms
# Speed: 13.4ms preprocess, 87.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 94.0ms
# Speed: 6.0ms preprocess, 94.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 115.2ms
# Speed: 6.9ms preprocess, 115.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 114.0ms
# Speed: 5.0ms preprocess, 114.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 110.1ms
# Is written True
# Speed: 6.6ms preprocess, 110.1ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp161.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp161.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp162.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp162.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp163.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp163.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp164.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp164.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp165.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp165.jpg
#
#
#
#
#
# 0: 640x512 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 99.9ms
# Speed: 1.5ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 99.0ms
# Speed: 7.5ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 99.6ms
# Speed: 6.0ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 107.0ms
# Speed: 5.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 106.4ms
# Speed: 8.1ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp166.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp166.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp167.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp167.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp168.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp168.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp169.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp169.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp170.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp170.jpg
#
#
#
#
#
# 0: 640x512 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 70.0ms
# Speed: 11.0ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 102.3ms
# Speed: 10.5ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 2 records, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 104.7ms
# Speed: 9.4ms preprocess, 104.7ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 96.7ms
# Speed: 6.0ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 2 overheads, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 2 demainer informations, 1 demining information, 107.7ms
# Speed: 7.0ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp171.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp171.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatA/zmp172.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatA/zmp172.jpg
# End clean, time took 30.337767839431763
# Folder ./jpg_minski_zapisnici_clean/FormatB
# Start clean...
# In:  ./jpg_minski_zapisnici_clean/FormatB/31146a.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31146a.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatB/31146b.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31146b.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatB/31153.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31153.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatB/31163a.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31163a.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatB/31164.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31164.jpg
#
#
#
#
#
#
#
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 80.4ms
# Speed: 21.0ms preprocess, 80.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 102.5ms
# Speed: 5.6ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 166.8ms
# Speed: 7.0ms preprocess, 166.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 480x640 1 overhead, 1 record, 1 map, 1 detailed information, 109.3ms
# Speed: 0.0ms preprocess, 109.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 101.5ms
# Speed: 11.2ms preprocess, 101.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 2 maps, 1 legend, 2 structures, 1 detailed information, 1 demainer information, 101.1ms
# Speed: 6.8ms preprocess, 101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x512 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 122.6ms
# Speed: 7.0ms preprocess, 122.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatB/31165.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31165.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatB/31167.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31167.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatB/31169a.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31169a.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatB/31169b.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31169b.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatB/31171.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/31171.jpg
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
#
#
# Is written True
#
#
#
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 92.7ms
# Speed: 18.0ms preprocess, 92.7ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 101.0ms
# Speed: 7.3ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 2 legends, 2 structures, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 103.1ms
# Speed: 2.9ms preprocess, 103.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 94.3ms
# Speed: 13.1ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x480 1 overhead, 1 record, 1 map, 1 legend, 111.9ms
# Speed: 4.8ms preprocess, 111.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# In:  ./jpg_minski_zapisnici_clean/FormatB/hcr_31157a.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/hcr_31157a.jpg
# In:  ./jpg_minski_zapisnici_clean/FormatB/hcr_31157b.jpg
# Out:  ./jpg_minski_zapisnici_clean_ml_regions/FormatB/hcr_31157b.jpg
# End clean, time took 1.8416223526000977
# 0: 640x416 1 overhead, 1 record, 2 maps, 1 legend, 1 structure, 1 detailed information, 1 unit record, 1 demainer information, 1 demining information, 73.4ms
# Speed: 7.1ms preprocess, 73.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 416)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True
# 0: 640x448 1 record, 1 map, 1 legend, 110.4ms
# Speed: 5.1ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Is written True
# Is written True
# Is written True
# Is written True
# Is written True

# %% [markdown]
# The results with the trained model is much better in all cases, so it will be used for further implementations

# %%
import os
output = "./jpg_minski_zapisnici_clean_ml_regions_separated"
if not os.path.isdir(f"./{output}"):
    os.mkdir(f"./{output}")
outputs = []
for i in range(9):
    output = f"./jpg_minski_zapisnici_clean_ml_regions_separated/reg_{i}"
    if not os.path.isdir(f"./{output}"):
        os.mkdir(f"./{output}")
    outputs.append(output)

# %% [markdown]
# From now on only Format A will be considered as it is the one that has latin text

# %%
import cv2
input = "./jpg_minski_zapisnici_clean_ml_regions/FormatA"
files = os.listdir(input)
for i, out in enumerate(outputs):
    suffix = f"_{i}.jpg"
    for file in files:
        if file.endswith(suffix):
            img = cv2.imread(f"{input}/{file}")
            cv2.imwrite(f"{out}/{file}", img)
